# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/proj004-p02-ml-models-hr-20230405/HRD_info.csv
# /kaggle/input/proj004-p02-ml-models-hr-20230405/HR_capstone_dataset.csv

# %% [markdown]
# <img style="float:left" src="https://i.imgur.com/DWQOJgU.png" width="1500">
#
# # ML Models - HR Analytics Data
# <hr>
# 5 May 2023

# %% [markdown]
# <div>
# <img style="float: left" src="https://i.postimg.cc/qvZpHzhk/002-Img-Objectives-Draft-2-20220819.png(https://postimg.cc/cvYpQ1Bj)" width="75">
# <h2 id="Obj1">Objectives</h2>
# <hr>
#
# <h3 style="text-align:justify">The HR department at Salifort Motors wants to take some initiatives to improve employee satisfaction levels at the company. The goals in this project are to analyze the data collected by the HR department and to build <b>a model that predicts whether or not an employee will leave the company</b> or <b> an employee will stay in the company</b>.
#
# by predicting employees likely to quit, it might be possible to identify factors that contribute to their leaving. Because it is time-consuming and expensive to find, interview, and hire new employees, increasing employee retention will be beneficial to the company.</h3>
# <p style = "font-family: Arial; font-size: 18px">Note: This project's dataset was created for pedagogical purposes and may not be indicative of Salifort Motors.</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Remember:</b><p style = "font-family:Verdana; font-size:14px">We must be <b>OBJECTIVE</b> in analyzing the data in order to acquire the valuable insights as opposed being biased and <b>UNDERSTAND</b> by collecting, fact checking or challenging the data and other sources. Go to where the data - Genchi Genbutsu attitudes. Data must be <b>Clear, Objective, Valuable, Focus, Agile, Scientific and Timeframe (COV-FAST)</b></p>
#     <p style = "font-family:Verdana; font-size:14px">There are other methodologies may be considered like, logistic regression, random forest or neural networking. We can use the same preprocessing dataset and try each options methodologies in seperate notebooks</p>
# </div>
#     <h3>Methodologies Overview</h3>
# <h3>Data Analysis PACE Steps:</h3>
#    <ol style="font-family:Verdana; font-size:16px">
#     <li><img style="float:left" src="https://i.imgur.com/gIne5bH.png" width="50"> Define (Plan & Analyze - EDA) - PART 1</li>
#     <blockquote>
#     <ol>Understand your data in the problem context
#         <br>EDA - check model, assumption & select model
#     </ol>
#     </blockquote>
#         <li><img style="float:left" src="https://i.imgur.com/rb8V6X5.png" width="50">Measure (Analyze - EDA)</li>
#     <blockquote>
#     <ol> EDA - check model, assumption & select model
#      </ol>
#     </blockquote>
#     <li><img style="float:left" src="https://i.imgur.com/J4M3HKM.png" width="50">Analyze (Construct) </li>
#     <blockquote>
#     <ol>Contruct and evaluate model
#      </ol>
#     </blockquote>
#     <li><img style="float:left" src="https://i.imgur.com/wpcEXQC.png" width="50">Improve (Execute) - interpret model and share the story</li>
#     <br>
#     <li>Control</li>

# %% [markdown]
# <h3 style = "text-align:center">Table 1.1. PACE Methodologies (Plan)</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <tr>
#     <th colspan="5">PACE 4 Steps</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Define<br>Plan</em></th>
#     <th colspan="3">Customer expectations of the process? <br>Understand your data in the problem context</th>
#   </tr>
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >A
#       </td>
#     <td>Identify Project's CTQ</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#       CTQ drill down tree,
#         VOC, Pareto, Bar Chart
#     </td>
#       <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#   <tr>
#      <tr>
#     <td style ="text-align:left" >B
#       </td>
#     <td>Define Process Mapping</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      SIPOC
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#     <td style ="text-align:left" >C
#       </td>
#     <td>Establish The Team's Charter</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Milestones, Team Members, Stakeholders, Project Charter
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#     <tr>
# <tr style = "border-top: solid ">
#     <th colspan="5">Data Analytics 6 Steps - Project Initiation and Planning Phase</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Ask and Prepare</em></th>
#     <th colspan="3">Customer expectations of the process? </th>
#   </tr>
#
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Ask - Mining
#       </td>
#     <td>A Clear Statement of The Business Task</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#       CTQ drill down tree,
#         VOC, Pareto, Bar Chart
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Ask - Mining
#       </td>
#     <td>Mapping Key Stakholders</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      RACI Matrix
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Prepare
#       </td>
#     <td>A Description of All Data Used</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Data Preparation or Gathering
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#  </table>

# %% [markdown]
# <img style="float:left" src="https://i.imgur.com/gIne5bH.png" width="80">
#
# ## Import the relevant libraries

# %%
# For data visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# For displaying all of the columns in dataframes
pd.set_option('display.max_columns', None)

# For data modeling
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# For metrics and helpful functions
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.tree import plot_tree

# For saving models
import pickle

# %% [markdown]
# ## Preprocessing
# ### Load info

# %%
raw_data=pd.read_csv('/kaggle/input/proj004-p02-ml-models-hr-20230405/HRD_info.csv',
                        index_col='Variable', encoding= 'unicode_escape')

# %%
df_info = raw_data.copy()

# %%
df_info.head(10)
# Out:
#                                                              Description
# Variable
# satisfaction_level        Employee-reported job satisfaction level [01]
# last_evaluation        Score of employee's last performance review [01]
# number_project                Number of projects employee contributes to
# average_monthly_hours  Average number of hours employee worked per month
# time_spend_company     How long the employee has been with the compan...
# Work_accident          Whether or not the employee experienced an acc...
# left                        Whether or not the employee left the company
# promotion_last_5years  Whether or not the employee was promoted in th...
# Department                                     The employee's department
# salary                              The employee's salary (U.S. dollars)

# %%
# Display all column names
### YOUR CODE HERE ### 
df_info.Description
# Out:
# Variable
# satisfaction_level          Employee-reported job satisfaction level [01]
# last_evaluation          Score of employee's last performance review [01]
# number_project                  Number of projects employee contributes to
# average_monthly_hours    Average number of hours employee worked per month
# time_spend_company       How long the employee has been with the compan...
# Work_accident            Whether or not the employee experienced an acc...
# left                          Whether or not the employee left the company
# promotion_last_5years    Whether or not the employee was promoted in th...
# Department                                       The employee's department
# salary                                The employee's salary (U.S. dollars)
# Name: Description, dtype: object

# %%
# Rename columns as needed
### YOUR CODE HERE ### 
df_info = df_info.rename(columns={'Work_accident': 'work_accident',
                          'average_montly_hours': 'average_monthly_hours',
                          'time_spend_company': 'tenure',
                          'Department': 'department'})

# Display all column names after the update
### YOUR CODE HERE ### 
df_info.Description
# Out:
# Variable
# satisfaction_level          Employee-reported job satisfaction level [01]
# last_evaluation          Score of employee's last performance review [01]
# number_project                  Number of projects employee contributes to
# average_monthly_hours    Average number of hours employee worked per month
# time_spend_company       How long the employee has been with the compan...
# Work_accident            Whether or not the employee experienced an acc...
# left                          Whether or not the employee left the company
# promotion_last_5years    Whether or not the employee was promoted in th...
# Department                                       The employee's department
# salary                                The employee's salary (U.S. dollars)
# Name: Description, dtype: object

# %% [markdown]
# #### Function to call the feature you want to know

# %%
def feat_info(col_name):
    print(df_info.loc[col_name]['Description'])

# %%
# Use capital in the first letter if keyword error
feat_info('promotion_last_5years')
# Out:
# Whether or not the employee was promoted in the last 5 years

# %% [markdown]
# ### Load the data

# %%
raw_data_1=pd.read_csv('/kaggle/input/proj004-p02-ml-models-hr-20230405/HR_capstone_dataset.csv')

# %%
df = raw_data_1.copy()

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# #### Missing values

# %%
df.isna().mean()
# Out:
# satisfaction_level       0.0
# last_evaluation          0.0
# number_project           0.0
# average_montly_hours     0.0
# time_spend_company       0.0
# Work_accident            0.0
# left                     0.0
# promotion_last_5years    0.0
# Department               0.0
# salary                   0.0
# dtype: float64

# %%
sns.set(style='whitegrid')

# %%
sns.heatmap(df.isna(), yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot: >

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">No missing values.</p>

# %%
df.describe().transpose()
# Out:
#                          count        mean        std    min     25%     50%  \
# satisfaction_level     14999.0    0.612834   0.248631   0.09    0.44    0.64
# last_evaluation        14999.0    0.716102   0.171169   0.36    0.56    0.72
# number_project         14999.0    3.803054   1.232592   2.00    3.00    4.00
# average_montly_hours   14999.0  201.050337  49.943099  96.00  156.00  200.00
# time_spend_company     14999.0    3.498233   1.460136   2.00    3.00    3.00
# Work_accident          14999.0    0.144610   0.351719   0.00    0.00    0.00
# left                   14999.0    0.238083   0.425924   0.00    0.00    0.00
# promotion_last_5years  14999.0    0.021268   0.144281   0.00    0.00    0.00
#
#                           75%    max
# satisfaction_level       0.82    1.0
# last_evaluation          0.87    1.0
# number_project           5.00    7.0
# average_montly_hours   245.00  310.0
# time_spend_company       4.00   10.0
# Work_accident            0.00    1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">2 Strings, the others are numeric.</p>

# %% [markdown]
# #### Rename columns

# %%
# Display all column names
### YOUR CODE HERE ### 
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
# Rename columns as needed
### YOUR CODE HERE ### 
df = df.rename(columns={'Work_accident': 'work_accident',
                          'average_montly_hours': 'average_monthly_hours',
                          'time_spend_company': 'tenure',
                          'Department': 'department'})

# Display all column names after the update
### YOUR CODE HERE ### 
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_monthly_hours', 'tenure', 'work_accident', 'left',
#        'promotion_last_5years', 'department', 'salary'],
#       dtype='object')

# %%
df.duplicated().mean()*100
# Out:
# 20.05467031135409

# %%
df.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df[df.duplicated()].head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 396                 0.46             0.57               2
# 866                 0.41             0.46               2
# 1317                0.37             0.51               2
# 1368                0.41             0.52               2
# 1461                0.42             0.53               2
#
#       average_monthly_hours  tenure  work_accident  left  \
# 396                     139       3              0     1
# 866                     128       3              0     1
# 1317                    127       3              0     1
# 1368                    132       3              0     1
# 1461                    142       3              0     1
#
#       promotion_last_5years  department  salary
# 396                       0       sales     low
# 866                       0  accounting     low
# 1317                      0       sales  medium
# 1368                      0       RandD     low
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Drop the 20% of duplicates</p>

# %%
# Drop duplicates and save resulting dataframe in a new variable as needed
### YOUR CODE HERE ###
df_1 = df.drop_duplicates(keep='first')

# Display first few rows of new dataframe as needed
df_1.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    tenure  work_accident  left  promotion_last_5years department  salary
# 0       3              0     1                      0      sales     low
# 1       6              0     1                      0      sales  medium
# 2       4              0     1                      0      sales  medium
# 3       5              0     1                      0      sales     low
# 4       3              0     1                      0      sales     low

# %% [markdown]
# ### EDA

# %%
plt.figure(figsize=(12,6))
sns.pairplot(df_1,hue="left", palette="coolwarm")
plt.suptitle("Distribution by left", fontsize=18, y=1)

plt.savefig('pairplot-hr-left.png', dpi=100)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">As we are measuring retention, we choose 'left' as the dependent variable (y) and based on the pair plot the independent variables (X) that show relation with the y are 'satisfaction level', 'last evaluation','number of project' and 'average monthly hours. For the aforementionded and the string or category data we will need to elaborate further.
# </p>

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
fig.suptitle('Features Distribution in HR Data',fontsize=16)

# Feature1
sns.boxplot(ax=axes[0,0],x = df_1['tenure'], palette="magma")
axes[0,0].set_title('tenure')

# Feature2
sns.boxplot(ax=axes[0,1],x = df_1['satisfaction_level'], palette="magma")
axes[0,1].set_title('satisfaction level')

# Feature3
sns.boxplot(ax=axes[0,2],x = df_1['last_evaluation'], palette="magma")
axes[0,2].set_title('last evaluation')

# Feature1
sns.kdeplot(ax=axes[1,0],data = df_1['tenure'], palette="magma")
axes[1,0].set_title('tenure')

# Feature2
sns.kdeplot(ax=axes[1,1],data = df_1['satisfaction_level'], palette="magma")
axes[1,1].set_title('satisfaction level')

# Feature3
sns.kdeplot(ax=axes[1,2],data = df_1['last_evaluation'], palette="magma")
axes[1,2].set_title('last evaluation')
# Out:
# /tmp/ipykernel_34/3697472717.py:17: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(ax=axes[1,0],data = df_1['tenure'], palette="magma")
# /tmp/ipykernel_34/3697472717.py:21: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(ax=axes[1,1],data = df_1['satisfaction_level'], palette="magma")
# /tmp/ipykernel_34/3697472717.py:25: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(ax=axes[1,2],data = df_1['last_evaluation'], palette="magma")
# Text(0.5, 1.0, 'last evaluation')

# %% [markdown]
# #### Handle outliers

# %%
df_1["tenure"].describe()
# Out:
# count    11991.000000
# mean         3.364857
# std          1.330240
# min          2.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         10.000000
# Name: tenure, dtype: float64

# %%
df_1["tenure"].quantile(0.92)
# Out:
# 5.0

# %%
df_out_tenure = round(df_1[df_1["tenure"] >= 6]['tenure'].count()/len(df_1)*100,2)

# %%
df_1[df_1["tenure"] >= 6]["tenure"].count()
# Out:
# 824

# %%
df_1[df_1["tenure"] >= 6]["left"].value_counts()
# Out:
# 0    715
# 1    109
# Name: left, dtype: int64

# %%
print('percentage of outliers upper 92% tenure',df_out_tenure,'%' )
# Out:
# percentage of outliers upper 92% tenure 6.87 %

# %%
# Determine the number of rows containing outliers 

# Compute the 25th percentile value in `tenure`
percentile25 = df_1['tenure'].quantile(0.25)

# Compute the 75th percentile value in `tenure`
percentile75 = df_1['tenure'].quantile(0.75)

# Compute the interquartile range in `tenure`
iqr = percentile75 - percentile25

# Define the upper limit and lower limit for non-outlier values in `tenure`
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print("Lower limit:", lower_limit)
print("Upper limit:", upper_limit)

# Identify subset of data containing outliers in `tenure`
outliers = df_1[(df_1['tenure'] > upper_limit) | (df_1['tenure'] < lower_limit)]

# Count how many rows in the data contain outliers in `tenure`
print("Number of rows in the data containing outliers in `tenure`:", len(outliers))
# Out:
# Lower limit: 1.5
# Upper limit: 5.5
# Number of rows in the data containing outliers in `tenure`: 824

# %%
ax = sns.countplot(x=df_1['left'],
                   order=df_1['left'].value_counts(ascending=False).index);
        
abs_values = df_1['left'].value_counts(ascending=False)
rel_values = df_1['left'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
plt.savefig('stayed_vs_left.png',dpi=100, bbox_inches = "tight")

# %% [markdown]
# <div class="alert alert-block alert-warning" style = "font-family: Arial; font-size: 16px">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><p style = "font-family:Verdana; font-size:14px">. Dataset is imbalanced
#
# <ul>To determine a metric to retain employee, consider the cost of both kinds of model error:
# <li> False positives (the model predicts employee stay, but the employee resign)
# <li> False negatives (the model predicts employee resign, but the employee stay)
# </ul></p>
# </div>

# %% [markdown]
# ## Define the Process
# <hr>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <h3 style = "text-align:center">Table 1.2. SIPOC Analysis</h3>
#   <tr>
#     <th>Supplier (S)
#     <th colspan="2">Input (I)</th>
#     <th colspan="4">Process (P)</th>
#     <th colspan="2">Output (O)</th>
#     <th colspan="2">Customer (C)</th>
#   </tr>
#     <td>Employee
#     <br>Dept Head</td>
#     <td colspan="2">Employee
#         <ul>
#             <li>Believe in your employee - Leadership
#             <li>Employee Empowerement - Personal growth
#             <li>Work ballance - Flexibility
#             <li>Company adequate professional information about company news
#             <li>Keep their morale high - Work satisfaction and recognition
#             <li>Establish a "healthy environment" - Work relationship
#             <li>Financial reward - salary,reward for loyalty and career prospect for high skill (peoplo who upgraded) or by tenure
#         </ul></td>
#     <td style="background:LightSkyBlue;text-align:center">Define key group of employees</td>
#     <td style="background:LightSkyBlue;text-align:center">Design retention plan</td>
#     <td style="background:LightSkyBlue;text-align:center">Assign employees to right plans</td>
#     <td style="background:LightSkyBlue">
#        Measure KPI, Report and Evaluate </td>
#         </td>
#     <td colspan="2" style="margin: auto; display:fill; word-wrap: break-word">
#         <ul>
#             <li>Turnover rate
#             <li>Loyalty Reward
#             <li>HR Engagement and Retention Report/Survey
#             <li>Employee performance report
#             <li>Promotion
#         </ul>
#     </td>
#     <td colspan="2" style="margin: auto; display:fill; word-wrap: break-word">
#         <ul>
#             <li>Dept Head
#             <li>HR
#         </ul>
#     </td>
#  </table>
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><p style = "font-family:Verdana; font-size:14px">Discussion should be conducted with the process' owner</p>
# </div>

# %% [markdown]
# ## Stakeholder Analysis
# <hr>
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">In this project we will only be mapping the stakeholders that were mentioned in articles or sources with high impacts and major role to the Salifort Motors project.</span>
#
# <h3 style = "text-align:center">Table 1.3. Stakeholder Analysis</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#   <tr>
#     <th>Stakeholders</th>
#     <th>Role</th>
#     <th colspan="2">Involvement</th>
#     <th>Power or Influence (H/M/L)</th>
#     <th>Interest (H/M/L)</th>
#     <th colspan="2">Engagement</th>
#   </tr>
#   <tr>
#     <td>HR Director</td>
#     <td style = "text-align:left">
#       Project sponsor
#     </td>
#     <td colspan="2" style ="text-align:left">
#     Makes high-level decisions; serves as team resource
#     </td>
#     <td style ="text-align:center">
#       H
#     </td>
#     <td style ="text-align:center">
#       L
#     </td>
#     <td colspan="2" style ="text-align:left">
#       Communicate regularly, but not daily. Ask questions and give updates.
#     </td>
#   </tr>
#   <tr>
#     <td>Dept Head</td>
#     <td style = "text-align:left">
#       Project owner
#     </td>
#     <td colspan="2" style ="text-align:left">
#      <ul>
#          <li>advisory role and providing valid information
#          <li>Implementation of preventive, diagnosis and treatment measures
#          <li>Allow re-export of surplus imported data or any required items to support project
#          <li>Formulation of the business requirements
#         <li>Formulation and implementation of equitable distribution of execution
#         </ul>
#     </td>
#     <td style ="text-align:center">
#       M
#     </td>
#     <td style ="text-align:center">
#       H
#     </td>
#     <td colspan="2" style ="text-align:left">
#       <ul>
#         <li>Informing, mentoring and coaching
#         <li>Monitoring the proper implementation of interventions
#         <li>Coordination in informing
#         <li>Official information reference in the Human Resource Management and
# control
#         <li>Training and consulting with other related organizations and institutions
#         </ul>
#     </td>
#   </tr>
#   <tr>
#     <td>HR Engagement and Retention</td>
#     <td style = "text-align:left">
#       Project leader
#     </td>
#     <td colspan="2" style ="text-align:left">
#      <ul>
#       <li>Project-rules making and planning
#      <li>Facilitate and synergy in inter-sectorial cooperation
#      <li>Identifying problems and providing solutions in the form of executive
#        approvals
#      </ul>
#     </td>
#     <td style ="text-align:center">
#       M
#     </td>
#     <td style ="text-align:center">
#       H
#     </td>
#     <td colspan="2" style ="text-align:left">
#        <ul>
#       <li>Synergy and strengthening of various capabilities across the team and organization,
#        directing and Mobilizing all capacities within the team.
#       <li>Lead project from the start to clossing.
#       </ul>
#     </td>
#   </tr>
#
#  </table>

# %% [markdown]
# <img style="float:left" src="https://i.imgur.com/rb8V6X5.png" width="50">
#
# ## Explarotary Data Analysis (EDA)

# %% [markdown]
# #### Number of project and average monthly hours

# %%
sns.lmplot(x='average_monthly_hours', y='number_project', data=df_1, hue='left', fit_reg=False, aspect=1)
plt.title('number project vs average monthly hours')
# Out:
# Text(0.5, 1.0, 'number project vs average monthly hours')

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 3, figsize = (22,8))

sns.scatterplot(x='average_monthly_hours', y='number_project', data=df_1, hue='left', ax=ax[0])
ax[0].set_title('Monthly hours by number of projects', fontsize='14')

# Create boxplot showing `average_monthly_hours` distributions for `number_project`, comparing employees who stayed versus those who left
sns.boxplot(data=df_1, x='average_monthly_hours', y='number_project', hue='left', orient="h", ax=ax[1])
ax[1].invert_yaxis()
ax[1].set_title('Monthly hours by number of projects', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
tenure_stay = df_1[df_1['left']==0]['number_project']
tenure_left = df_1[df_1['left']==1]['number_project']
sns.histplot(data=df_1, x='number_project', hue='left', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Number of projects', fontsize='14')

# Display the plots
plt.savefig('Monthly-hours-by-number-of-projects.png')
plt.show()

# %%
# Get value counts of stayed/left for employees with 7 projects
df_1[df_1['number_project']==7]['left'].value_counts()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Employee who had done 7 porjects, had  left. The graph shows that skewed to the left.
# </p>

# %%
# Get value counts of stayed/left for employees with 7 projects
df_1[df_1['number_project']==7]['average_monthly_hours'].describe()

# %%
# Get value counts of stayed/left for employees with 6 projects
df_1[df_1['number_project']==6]['left'].value_counts()

# %%
# Get statistic of stayed/left for employees with 7 projects
df_1[df_1['number_project']==6]['average_monthly_hours'].describe()

# %%
# Get statistic of average monthly hours for employees with min hours 6 projects
df_1[(df_1['number_project']==6) & (df_1['left'] == 1)]['average_monthly_hours'].describe()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Employee with 7 projects minimum worked 133 hours/month and the max work 310 hours/month, left the company. The most people who left the company, go to the people who had worked 6 projects with minimum worked 134 hours/month and max to 310 hours/month. If we assume a work week of 40 hours and two weeks of vacation per year, then the average number of working hours per month of employees working Monday&ndash;Friday `= 50 weeks * 40 hours per week / 12 months = 166.67 hours per month`.
#     </p>

# %%
# Get value counts of stayed/left for employees with min hours project seven
df_1[(df_1['number_project']==7) & (df_1['average_monthly_hours'] > 166.67)]['left'].value_counts()

# %%
# Get percent of stayed/left for employees with min hours project 7
percent_7_proj_ot = df_1[(df_1['number_project']==7) & (df_1['average_monthly_hours'] > 166.67)]['left'].value_counts()/len(df_1['number_project'])*100
percent_7_proj_ot

# %%
# Get statistic of number of project =3 and stayed
df_1[(df_1['number_project']==3) & (df_1['left'] == 0)]['average_monthly_hours'].describe()

# %%
# Get statistic of number of project =2 and stayed
df_1[(df_1['number_project']==2) & (df_1['left'] == 0)]['average_monthly_hours'].describe()

# %% [markdown]
# <div style ="font-family:Verdana; font-size:16px; text-align:justify">As we analyze it deeper, as the graph above that there people left the company either resign or being laid off (reason for leave is not in the data, this can be considered to be added next if necessary) show increasing number of project also an increase of total hours.
# <ol>
# <li>We have 143 employee who work more than normal hours and 2 employee who work than less normal hours per month. In the first people, will be the employee that work over time due to the number of the project(s). The later we can assumed that the employee may have resigned or fired before the normal hours in the month are completed.
#
#  <li>If we look also to employees who stay , there are data of employees that work below normal average hours and there are other possibillity that there may have been employees who had work twice hours in a day  for 2 weeks before leaving/still staying (at least 160 hours/biweekly), this may be due incorrect input/data and for the later, a data of date of leaving can help confirm the data further.
#
# <li>The optimal number of projects for employees to work on seems to be 3&ndash;4. The ratio of left/stayed is very small for these cohorts. More, for 2 projects we can see that the employees who left are working less than normal average monthly hours.
#
# <li>It can be said that employes work over time with their projects.
#     </ol><br>
# As the next step, you could confirm that all employees with seven projects left.
# </div>

# %% [markdown]
# #### Average monthly hours and tenure

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 3, figsize = (22,8))

sns.scatterplot(x='average_monthly_hours', y='tenure', data=df_1, hue='left', ax=ax[0])
ax[0].set_title('Monthly hours by tenure', fontsize='14')

# Create boxplot showing `average_monthly_hours` distributions for `number_project`, comparing employees who stayed versus those who left
sns.boxplot(data=df_1, x='average_monthly_hours', y='tenure', hue='left', orient="h", ax=ax[1])
ax[1].invert_yaxis()
ax[1].set_title('Monthly hours by tenure', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
tenure_stay = df_1[df_1['left']==0]['tenure']
tenure_left = df_1[df_1['left']==1]['tenure']
sns.histplot(data=df_1, x='tenure', hue='left', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Tenure', fontsize='14')

# Display the plots
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">We have seen  in the pair plot above and we enlarge the graph that show the tenure below 7 years where employees left the company. With 3 years the highest employees left.
#     </p>

# %% [markdown]
# #### Average monthly hours and satisfaction level

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Create scatterplot of `average_monthly_hours` versus `satisfaction_level`, comparing employees who stayed versus those who left
plt.figure(figsize=(16, 9))
sns.scatterplot(data=df_1, x='average_monthly_hours', y='satisfaction_level', hue='left', alpha=0.6)
plt.axvline(x=166.67, color='red', label='166.67 hrs./mo.', ls='--')
plt.legend(labels=['166.67 hrs./mo.', 'stayed', 'left'])
plt.title('Monthly hours by satisfaction level', fontsize='14');

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">We have seen  in the pair plot above. The scatterplot above shows that there was a sizeable group of employees who worked ~240&ndash;315 hours per month. 315 hours per month is over 75 hours per week for a whole year. It's likely this is related to their satisfaction levels being close to zero.
#
# The plot also shows another group of people who left, those who had more normal working hours. Even so, their satisfaction was only around 0.4. It's difficult to speculate about why they might have left. It's possible they felt pressured to work more, considering so many of their peers worked more. And that pressure could have lowered their satisfaction levels.
#
# Finally, there is a group who worked ~210&ndash;280 hours per month, and they had satisfaction levels ranging ~0.7&ndash;0.9.
#
# Note the strange shape of the distributions here. This is indicative of data manipulation or synthetic data.
#     </p>

# %% [markdown]
# #### Average monthly hours and last evaluation

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Create scatterplot of `average_monthly_hours` versus `satisfaction_level`, comparing employees who stayed versus those who left
plt.figure(figsize=(16, 9))
sns.scatterplot(data=df_1, x='average_monthly_hours', y='last_evaluation', hue='left', alpha=0.6)
plt.axvline(x=166.67, color='red', label='166.67 hrs./mo.', ls='--')
plt.legend(labels=['166.67 hrs./mo.', 'stayed', 'left'])
plt.title('Monthly hours by last evaluation', fontsize='14');

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">We have seen  in the pair plot above. The scatterplot is enlarge above shows that there was a sizeable group of employees who worked ~240&ndash;315 hours per month. 315 hours per month with high last evaluation result more than 0.75 .
#
# The plot also shows another group of people who left, those who had more normal working hours. Even so, their grade was only around 0.45 to 0.6. It's difficult to speculate about why they might have left. There isn't a high percentage of employees in the upper left quadrant of this plot; but working long hours doesn't guarantee a good evaluation score.
#
# Note the strange shape of the distributions here. This is indicative of data manipulation or synthetic data.
#     </p>

# %% [markdown]
# #### Satisfaction level by tenure

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 3, figsize = (22,8))

sns.scatterplot(x='satisfaction_level', y='tenure', data=df_1, hue='left', ax=ax[0])
ax[0].set_title('Satisfaction level by tenure', fontsize='14')

# Create boxplot showing `average_monthly_hours` distributions for `number_project`, comparing employees who stayed versus those who left
sns.boxplot(data=df_1, x='satisfaction_level', y='tenure', hue='left', orient="h", ax=ax[1])
ax[1].invert_yaxis()
ax[1].set_title('Satisfaction level by tenure', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
tenure_stay = df_1[df_1['left']==0]['tenure']
tenure_left = df_1[df_1['left']==1]['tenure']
sns.histplot(data=df_1, x='tenure', hue='left', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Tenure', fontsize='14')

# Display the plots
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">There are many observations you could make from this plot.
#     <ul>
# <li> Employees who left fall into two general categories: dissatisfied employees with shorter tenures and very satisfied employees with medium-length tenures.
# <li> Four-year employees who left seem to have an unusually low satisfaction level. It's worth investigating changes to company policy that might have affected people specifically at the four-year mark, if possible.
# <li> The longest-tenured employees didn't leave. Their satisfaction levels aligned with those of newer employees who stayed.
# <li> The histogram shows that there are relatively few longer-tenured employees. It's possible that they're the higher-ranking, higher-paid employees.
#     </ul>
# As the next step in analyzing the data, you could calculate the mean and median satisfaction scores of employees who left and those who didn't.
# </p></div>

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
df_1.groupby(['left'])['satisfaction_level'].agg([np.mean,np.median])

# %% [markdown]
# As expected, the mean and median satisfaction scores of employees who left are lower than those of employees who stayed. Interestingly, among employees who stayed, the mean satisfaction score appears to be slightly below the median score. This indicates that satisfaction levels among those who stayed might be skewed to the left.

# %% [markdown]
# #### Last evaluation by satisfaction level

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Create scatterplot of `satisfaction level versus `satisfactionlevel`, comparing employees who stayed versus those who left
plt.figure(figsize=(16, 9))
sns.scatterplot(data=df_1, x='last_evaluation', y='satisfaction_level', hue='left', alpha=0.6)
plt.title('Last evaluation by satisfaction level', fontsize='14')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">We have seen  in the pair plot above and we enlarge the graph that show high evaluation in the  ~0.75 to 1 have near to 0 satisfcatory level and left. For the staying employees, we can see that high evaluation results not necessary mean  high satisfactory towards he company.
#     </p>

# %% [markdown]
# #### Average monthly hours by promotion last 5 years

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Create plot to examine relationship between `average_monthly_hours` and `promotion_last_5years`
plt.figure(figsize=(16, 3))
sns.scatterplot(data=df_1, x='average_monthly_hours', y='promotion_last_5years', hue='left', alpha=0.4)
plt.axvline(x=166.67, color='#ff6361', ls='--')
plt.legend(labels=['166.67 hrs./mo.', 'stayed', 'left'])
plt.title('Monthly hours by promotion last 5 years', fontsize='14');

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The plot above shows the following:
#     <ul>
# <li> very few employees who were promoted in the last five years left
# <li> very few employees who worked the most hours were promoted
# <li> all of the employees who left were working the longest hours
#     </ul>
# </p>

# %% [markdown]
# #### Category vs left

# %%
df_1.select_dtypes(['object']).columns

# %% [markdown]
# #### Salary vs tenures

# %%
ax = sns.countplot(x=df_1['salary'],
                   order=df_1['salary'].value_counts(ascending=False).index);
        
abs_values = df_1['salary'].value_counts(ascending=False)
rel_values = df_1['salary'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
plt.savefig('salary-distribution.png')

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Set figure and axes
fig, ax = plt.subplots(1, 2, figsize = (22,8))

# Define short-tenured employees
tenure_short = df_1[df_1['tenure'] < 7]

# Define long-tenured employees
tenure_long = df_1[df_1['tenure'] > 6]

# Plot short-tenured histogram
sns.histplot(data=tenure_short, x='tenure', hue='salary', discrete=1, 
             hue_order=['low', 'medium', 'high'], multiple='dodge', shrink=.5, ax=ax[0])
ax[0].set_title('Salary histogram by tenure: Short-tenured people', fontsize='14')

# Plot long-tenured histogram
sns.histplot(data=tenure_long, x='tenure', hue='salary', discrete=1, 
             hue_order=['low', 'medium', 'high'], multiple='dodge', shrink=.4, ax=ax[1])
ax[1].set_title('Salary histogram by tenure: Long-tenured people', fontsize='14')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The plots above show that long-tenured employees were not disproportionately comprised of higher-paid employees. We can see long-tenured is small proportion with more of medium salary and for low tenure has a majority proportion with medium to low salary more.
#     </p>

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Set figure and axes
fig, ax = plt.subplots(1, 2, figsize = (22,8))

# Define tenure-stay employees
tenure_stay = df_1[df_1['left']==0]
tenure_left = df_1[df_1['left']==1]

# Plot short-tenured histogram
sns.histplot(data=tenure_stay, x='tenure', hue='salary', discrete=1, 
             hue_order=['low', 'medium', 'high'], multiple='dodge', shrink=.5, ax=ax[0])
ax[0].set_title('Salary histogram by tenure: Stay-tenured people', fontsize='14')

# Plot long-tenured histogram
sns.histplot(data=tenure_left, x='tenure', hue='salary', discrete=1, 
             hue_order=['low', 'medium', 'high'], multiple='dodge', shrink=.4, ax=ax[1])
ax[1].set_title('Salary histogram by tenure: Left-tenured people', fontsize='14');

plt.savefig('Stayed-and-left-by-salary.png')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The plots above show that employees who <b>stayed</b> were not disproportionately comprised of higher-paid employees. In addition, we can see that low and medium salary fall into the people who <b>left</b> the company with 3 to 5 years.
#     </p>

# %%
df_1['salary'].value_counts()

# %%
percent_low_salary=df_1[df_1['salary']=='low']['salary'].value_counts()/len(df_1['salary'])
print('percent of low salary', percent_low_salary,'%')

# %% [markdown]
# #### satisfaction level by salary

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 3, figsize = (22,8))

sns.scatterplot(x='satisfaction_level', y='salary', data=df_1, hue='left', ax=ax[0])
ax[0].set_title('Satisfaction level by salary', fontsize='14')
ax[0].invert_yaxis()
# Create boxplot showing `average_monthly_hours` distributions for `number_project`, comparing employees who stayed versus those who left
sns.boxplot(data=df_1, x='satisfaction_level', y='salary', hue='left', orient="h", ax=ax[1])
ax[1].invert_yaxis()
ax[1].set_title('Satisfaction level by salary', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
sns.histplot(data=df_1, x='left', hue='salary', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Left by salary', fontsize='14')

# Display the plots
plt.savefig('Satisfaction by salary.png')
plt.show()

# %%
df_1[df_1['satisfaction_level']>0.75]['salary'].value_counts()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Based on the data high salary around 8% and were not disproportionately comprised of higher-satisfactory employees. The medium and low salary who left tend to <b>have lower satiscation for the company</b>.
#     </p>

# %% [markdown]
# #### last evaluation by salary

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 3, figsize = (22,8))

sns.scatterplot(x='last_evaluation', y='salary', data=df_1, hue='left', ax=ax[0])
ax[0].set_title('Last evaluation by salary', fontsize='14')
ax[0].invert_yaxis()
# Create boxplot showing `average_monthly_hours` distributions for `number_project`, comparing employees who stayed versus those who left
sns.boxplot(data=df_1, x='last_evaluation', y='salary', hue='left', orient="h", ax=ax[1])
ax[1].invert_yaxis()
ax[1].set_title('Last evaluation by salary', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
sns.histplot(data=df_1, x='left', hue='salary', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Left by salary', fontsize='14')

# Display the plots
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Based on the data <b>high salary around 8%</b> and were not disproportionately comprised of higher-graded employees. Employee with all type of salary who left have ~0.5-0.9 last evaluation score  and stayed with ~0.6-0.85.
#     </p>

# %% [markdown]
# #### Top (evaluation 0.8 up)

# %%
df_1[df_1['last_evaluation'] >=0.8].groupby('left').count()['salary'].sort_values(ascending=False)

# %%
df_1[(df_1['last_evaluation']>=0.8) & (df_1['left'] == 1)]['salary'].value_counts()

# %%
df_top_left = df_1[(df_1['last_evaluation']>=0.8) & (df_1['left'] == 1)]['salary'].value_counts()

# %%
df_pareto_top = pd.DataFrame(df_top_left)
df_pareto_top

# %%
pareto = 100 *df_pareto_top.salary.cumsum() / df_pareto_top.salary.sum()
df_pareto_top['Percentage']= pareto
df_pareto_top

# %%
df_1[df_1['last_evaluation'] >=0.8].groupby('left').mean()

# %%
top_evaluation = df_1[df_1['last_evaluation'] >=0.8].groupby('left').mean()
top_evaluation

# %% [markdown]
# #### Medium (evaluation 0.59 - 0.8)

# %%
df_1[(df_1['last_evaluation']>=0.6) & (df_1['last_evaluation'] < 0.8)].groupby('left').count()['salary'].sort_values(ascending=False)

# %%
df_1[(df_1['last_evaluation']>=0.6) & (df_1['last_evaluation'] < 0.8) & (df_1['left'] == 1)]['salary'].value_counts()

# %%
df_medium_left = df_1[(df_1['last_evaluation']>=0.6) & (df_1['last_evaluation'] < 0.8) & (df_1['left'] == 1)]['salary'].value_counts()

# %%
df_pareto_medium = pd.DataFrame(df_medium_left)
df_pareto_medium

# %%
pareto = 100 *df_pareto_medium.salary.cumsum() / df_pareto_medium.salary.sum()
df_pareto_medium['Percentage']= pareto
df_pareto_medium

# %%
df_1[(df_1['last_evaluation']>=0.6) & (df_1['last_evaluation'] < 0.8)].groupby('left').mean()

# %% [markdown]
# #### Low (evaluation below 0.6)

# %%
df_1[df_1['last_evaluation'] < 0.6].groupby('left').count()['salary'].sort_values(ascending=False)

# %%
df_1[(df_1['last_evaluation'] < 0.6) & (df_1['left'] == 1)]['salary'].value_counts()

# %%
df_low_left = df_1[(df_1['last_evaluation'] < 0.6) & (df_1['left'] == 1)]['salary'].value_counts()

# %%
df_pareto_low = pd.DataFrame(df_low_left)
df_pareto_low

# %%
pareto = 100 *df_pareto_low.salary.cumsum() / df_pareto_low.salary.sum()
df_pareto_low['Percentage']= pareto
df_pareto_low

# %%
df_1[df_1['last_evaluation'] < 0.6].groupby('left').mean()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Based on the data employee who left
#     <ul>Top (evaluation more and equal to 0.8):
#         <li>Who stayed have higher satisfaction level, lower number of project and lower average monthly hours.
#         <li>Who left the company in the top evaluation with high salary is 2% and more than 98% from the group with medium to low salary.</ul>
#     <ul>Medium (evaluation between 0.59 to 0.6):
#         <li>Who stayed have higher satisfaction level, lower number of project and lower average monthly hours.
#         <li>Who left in the company in the middle evaluation only consist of almost 60:40 for medium  and low salary, </ul>
#     <ul>Low (evaluation lower than 0.6):
#         <li>Who stayed have higher average satisfaction level, higher average number of project and average monthly hours.
#         <li>Who left the company in the low evaluation with high salary is 4% and more than 96% from the group with medium to low salary. </ul>
# </p>

# %%
top = df_1['last_evaluation'] >=0.8
medium = (df_1['last_evaluation'] >=0.6) & (df_1['last_evaluation'] <0.8)
low = df_1['last_evaluation'] <0.6

# %%
top.value_counts()

# %%
df_top_perform = pd.DataFrame(top.value_counts())
df_top_perform

# %%
pareto = 100 *df_top_perform.last_evaluation.cumsum() /df_top_perform.last_evaluation.sum()
df_top_perform['Percentage']= pareto
df_top_perform

# %%
medium.value_counts()

# %%
low.value_counts()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The high evaluation employee consist of 38% and more than 62% Employee have medium and low evaluation.
#     </p>

# %% [markdown]
# #### Departments by left

# %%
# Display counts for each department
df_1["department"].value_counts()

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Create stacked histogram to compare department distribution of employees who left to that of employees who didn't
plt.figure(figsize=(11,8))
sns.histplot(data=df_1, x='department', hue='left', discrete=1, 
             hue_order=[0, 1], multiple='dodge', shrink=.5)
plt.xticks(rotation=45)
plt.title('Counts of stayed/left by department', fontsize=14);

# %%
ax = sns.countplot(x=df_1['salary'],
                   order=df_1['salary'].value_counts(ascending=False).index);
        
abs_values = df_1['salary'].value_counts(ascending=False)
rel_values = df_1['salary'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)

# %% [markdown]
# #### Pareto salary by left

# %%
df_1[df_1['left'] == 1].groupby('salary').count()['left'].sort_values(ascending=False)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">People who left the most have low salaries
#     </p>

# %% [markdown]
# #### Pareto department by left

# %%
df_1[df_1['left'] == 1].groupby('department').count()['left'].sort_values(ascending=False)

# %%
df_dept_left = df_1[df_1['left'] == 1].groupby('department').count()['left'].sort_values(ascending=False)
#df_dept_left.columns

# %%
df_pareto = pd.DataFrame(df_dept_left)
df_pareto

# %%
pareto = 100 *df_pareto.left.cumsum() / df_pareto.left.sum()
df_pareto['Percentage']= pareto
df_pareto

# %%
plt.figure(figsize=(22,8))
# creating axes object and defining plot
ax = df_pareto.plot(kind = 'bar',use_index=True,
                    y = 'left', color = 'Blue',
                    linewidth = 3)

ax2 = df_pareto.plot(kind = 'line', use_index=False,
                y = 'Percentage', secondary_y = True,
                color = 'Orange', linewidth = 3, marker='D',
                ax = ax)

#title of the plot
plt.title("Pareto employee left by department")

#labeling x and y-axis
ax.set_xlabel('department', color = 'g')
for dept in ax.get_xticklabels():#ax.set_xticklabels(ax.get_xticks(), rotation = 45) - no depy name
    dept.set_rotation(45)#plt.xticks(rotation = 45) - unable to change
ax.set_ylabel('left', color = "b")
ax2.set_ylabel('Percentage', color = 'r')

#defining display layout
plt.tight_layout()
#fig, axes = plt.subplots()
ax.legend(loc='center right', frameon=False)

ax2.hlines(y=80, xmin=0, xmax=4.5, linewidth=2, color='r',ls='--')
ax.vlines(x=4.5, ymin=0, ymax=400, linewidth=2, color='r',ls='--')
#show plot

plt.savefig('pareto-department.png')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Based on pareto principle the department that according to the 80% would be sales, technical, support, IT and HR. moreover, it seems marketing, product and accounting almost have similar employee who left.
#     </p>

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Plot a correlation heatmap
plt.figure(figsize=(16, 9))
heatmap = sns.heatmap(df_1.corr(), vmin=-1, vmax=1, annot=True, cmap=sns.color_palette("coolwarm", as_cmap=True))
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':14}, pad=12)

# %%
plt.figure(figsize=(12,6))
df_1.corr()['left'].sort_values(ascending=False).iloc[1:].plot(kind='bar')
#plt.tight_layout()

plt.savefig('Correlation-by-left.png',dpi=100, bbox_inches = "tight")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Insights:</b><p style = "font-family:Verdana; font-size:14px">Positive correlation with tenure, average monthly hours, number of project and last evaluation. Negatively with promotion last 5 years and satisfaction level.
# <br>
# Based on the data employee who left generally, have lower in satisfaction level, high number of project and average monthly hours. It can be ungratifying to work long hours and not receive promotions, increase in salary or good evaluation scores. There's a sizeable group of employees at this company who are probably burned out.
#     <ul>Top (evaluation more and equal to 0.8):
#         <li>Who stayed have higher average satisfaction level, lower average number of project and lower average monthly hours.
#         <li>Who left the company in the top evaluation with average high average salary is 2% and more than 98% from the group with medium to low average salary.</ul>
#     <ul>Medium (evaluation between 0.59 to 0.8):
#         <li>Who stayed have higher satisfaction level, lower average number of project and lower average monthly hours.
#         <li>Who left in the company in the middle evaluation only consist of almost 60:40 for medium  and low average salary, </ul>
#     <ul>Low (evaluation lower than 0.6):
#         <li>Who stayed have higher average satisfaction level, higher average number of project and average monthly hours.
#         <li>Who left the company in the low evaluation with high average salary is 4% and more than 96% are from the group with medium to low salary. </ul>
#     Employee tend not to leave for tenure more than 6 years.
# </p>

# %% [markdown]
# <h3 style = "text-align:center">Table 1.4. Project Charter</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#   <tr>
#     <th colspan ="4" style="text-align:center">Project HR Employee Retention</th>
#   </tr>
#     <tr>
#     <th colspan ="4" style="text-align:center">5th May 2023</th>
#   </tr>
#   <tr>
#       <th colspan ="4" style="text-align:center">Document Status: <del>Draft</del> | In Review | <del>Approved</del></th>
#   </tr>
#   <tr>
#       <th colspan ="4" style="text-align:center">Executive Summary</th>
#   </tr>
#   <tr>
#       <td colspan ="4" style="text-align:center">develop a model that predicts employee churn (stayed or left) profile.</td>
#   </tr>
#   <tr style ="background:LightSkyBlue;text-align:center">
#       <td colspan ="2">Business Case</td>
#       <td colspan ="2">Problem/Opportunity Statement</td>
#   </tr>
#  <tr style="text-align:left">
#       <td colspan ="2">Through excellent employee retention (also known as retention program or retention management), outstanding performance can not only be maintained, but also promoted and maximized for the company. Based on the <b>there are 17% employees that left the company, approximately 1,991 employees</b> along the years (the year of the resignation or terminatiion not mentioned). Employees who identify with the company feel more responsible. Fluctuation is reduced, absenteeism due to illness is reduced and the quality of work results is higher. All this and many other effects of high employee loyalty increase success and minimize avoidable costs. Another challenge will be the remote work culture and chat-gpt that change the working environment can affect performance.
#           <br><br>
# HR estimates for a 200-employee-sized business,with 17% turnover rate that’s 34 departures every year. In compensation terms, the real cost of employee turnover can be upward of 30% and cost up to five times the position’s annual compensation, depending on the type of role, location, etc.
# <br><br>
# By calculating reasonable estimates for expenses like employee annual salary and daily cost of covering vacancy, that 200-employee business would spend <b>estimated more than $500,000 in avoidable costs</b>.
# </td>
#       <td colspan ="2"><em>In this project</em> we establish a model to find ways to<b> predict profile that likely to churn. </b>
# <br><br>The goal of selective employee retention is to identify and retain people who are relevant to success. So-called "top performers" typically have the following roles:
# <ol>
# <li>Performers (high and top performers)
# <ul> <b>Based on the data high salary around 8% and were not disproportionately comprised of higher-graded employees.</b>
#     <li>Potential carriers (promising talents)
#     <li>Holders of positions of high strategic importance
#     <li>Experts with expertise or skills that are rarely available on the market
# </ul>
# <li>Mid-performers", can also be developed into "top performers" with good personnel and management work. <b>Based on the data medium salary around 44% and were not disproportionately comprised of medium-graded employees.</b>
# <li>"Low-performers" are resistant to measures for employee retention and boycotting, often even measures to improve employee satisfaction or retention. That is why the (main) focus of all measures for employee retention is on top and mid-performers. <b>Based on the data high salary around 48% and were not disproportionately comprised of lower-graded employees.</b>
#           </ol>
#      </td>
#   </tr>
#
#  <tr style ="background:LightSkyBlue;text-align:center">
#       <td colspan ="2">Goal Statement</td>
#       <td colspan ="2">Deliverables (Key Results)</td>
#  </tr>
#  <tr style="text-align:left">
#       <td colspan ="2">Primary metric:
#      <ul>
#          <li>Employee retention Rate - build a model that predict employee who stayed or left.
#      </ul>
#      Secondary Metric:
#      <ul>
#          <li>Average monthly hours
#          <li>Evaluation
#      </ul>
#      </td>
#       <td colspan ="2">Primary Key Results:
#      <ul>
#          <li>Increase retention rate - reduce 50% of people leaving the company (the data provide the employee who stayed and left).
#      </ul>
#      Secondary Key Results:
#      <ul>
#          <li>Number of project
#          <li>Top and Medium evaluation distribution
#      </ul>
#      </td>
#   </tr>
#
#  <tr style ="background:LightSkyBlue;text-align:center">
#       <td colspan ="2">Benefits, Cost, and Budget</td>
#       <td colspan ="2">Scope and Exclusion</td>
#  </tr>
#  <tr style="text-align:left">
#       <td colspan ="2">Benefits:
#      <ul>
#          <li>Reducing 50% of employees (for 200 employees) leaving the company estimated more than $250,000 in avoidable costs.
#          <li>Increase tenure
#          <li>Increse satisfaction
#          <li>Increase top performer
#      </ul>
#      Costs:
#      <ul>
#          <li>Recruitment cost
#          <li>Training cost
#      </ul>
#      Budget Needed:
#            <span>TBD</span>
#      </td>
#       <td colspan ="2">In-Scope:
#      <ul>
#          <li>All department
#          <li>Top and medium evaluation
#          <li>Full time
#      </ul>
#      Out-of-Scope:
#      <ul>
#          <li>Part Time or contract
#          <li>Lean measure such as ,Fastest recruitment etc.
#      </ul>
#      </td>
#   </tr>
#
#  <tr style ="background:LightSkyBlue;text-align:center">
#       <td colspan ="2">Project Team</td>
#       <td colspan ="2">Measuring Success</td>
#  </tr>
#  <tr style="text-align:left">
#       <td colspan ="2">
#      <ul>
#          <li>Sponsor: Laura, Director of HR
#          <li>Owner: Washington, Operations Manager
#          <li>Leader:Joko, Senior
#              HR Engagement and Retentioan
#          <li>Member: Denzel, Data Analysis Manager, jennifer, Senior Data Analyst, Wahyu Senior Data Analyst
#      </ul>
#      </td>
#
#   <td colspan ="2">Deliverables after solutions implementation:
#      <ul>
#          <li>Increase retention rate and turnover rate
#          <li>Increase employee engagement and retention survey
#          <li>Increase employee performance
#      </ul>
#   </td>
#   </tr>
#   </table>

# %% [markdown]
# <img style="float:left" src="https://i.imgur.com/J4M3HKM.png" width="50">
#
# ## Construct Stage (Data Partitioning)
#
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Notes:</b><p style = "font-family:Verdana; font-size:14px"> <b>Partitioned linear regression</b> a technique used to subdivide the independent variables in two groups and estimate their coefficients in two separate steps.</p>
# </div>
#
# ## Model 1: Logistic Regression (1)
#
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Notes:</b><p style = "font-family:Verdana; font-size:14px"> <b>Logistic regression is quite sensitive to outliers, We have seen that there are outliers in the `tenure` column but as the upper outliers show the employee. that work above 5 years, we decided to keep the variable</p>
# </div>

# %%
df_1.select_dtypes(['object']).columns

# %%
# Dummy the categorical variables as needed and save resulting dataframe in a new variable
df_dummy_1 = pd.get_dummies(df_1, prefix=['salary', 'dept'], columns = ['salary', 'department'], drop_first=False)

# Display the new dataframe
df_dummy_1.head()

# %%
df.to_csv('/kaggle/working/Proj004-P02-ML-Models-HR-Analytics-20230505-dummy-1.csv', index=False)

# %% [markdown]
# #### Dependent and independent variables

# %%
x1 = df_dummy_1['satisfaction_level'] 
x2 = df_dummy_1['last_evaluation']
x3 = df_dummy_1['number_project']
x4 = df_dummy_1['average_monthly_hours']
x5 = df_dummy_1['tenure']
x6 = df_dummy_1['promotion_last_5years']
y = df_dummy_1['left']

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10), sharey=True)
fig.suptitle('Left')

# Satisfaction level
sns.regplot(ax=axes[0,0], x=x1, y=y, data=df_dummy_1, logistic=True, ci=None)
axes[0,0].set_title('Satisfaction level')

# Last evaluation
sns.regplot(ax=axes[0,1], x=x2, y=y, data=df_dummy_1, logistic=True, ci=None)
axes[0,1].set_title('Last evaluation')

# Number of project
sns.regplot(ax=axes[0,2], x=x3, y=y, data=df_dummy_1, logistic=True, ci=None)
axes[0,2].set_title('Number of project')

# Satisfaction level
sns.regplot(ax=axes[1,0], x=x4, y=y, data=df_dummy_1, logistic=True, ci=None)
axes[1,0].set_title('Average monthly hours')

# Last evaluation
sns.regplot(ax=axes[1,1], x=x5, y=y, data=df_dummy_1, logistic=True, ci=None)
axes[1,1].set_title('Tenure')

# Number of project
sns.regplot(ax=axes[1,2], x=x6, y=y, data=df_dummy_1, logistic=True, ci=None)
axes[1,2].set_title('Promotion last 5 years')

plt.savefig('reg-six-plots', dpi=100, bbox_inches = "tight")

# %% [markdown]
# ### Split, Train and Test Data

# %%
X = df_dummy_1.drop('left',axis=1)
y = df_dummy_1['left']

# %% [markdown]
# #### Training model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
clf = LogisticRegression()
clf = clf.fit(X_train,y_train)

# %% [markdown]
# #### Parameter estimates

# %%
clf.coef_

# %%
clf.intercept_

# %% [markdown]
# #### Prediction and evaluation

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# #### Confusion matrix

# %%
# Compute values for confusion matrix
log_cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)

# Create display of confusion matrix
log_disp = ConfusionMatrixDisplay(confusion_matrix=log_cm, display_labels=clf.classes_)

# Plot confusion matrix
log_disp.plot()

# Display plot
plt.show()

# %%
df_dummy_1['left'].value_counts(normalize=True)

# %%
# Create classification report for logistic regression model
target_names = ['Predicted would not leave', 'Predicted would leave']
print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test,y_pred))
print('\n')
print(accuracy_score(y_test,y_pred))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The classification report above shows that the logistic regression model achieved a precision of 79%, recall of 83%, f1-score of 70% (all weighted averages), and accuracy of 83%.
#     </p>

# %% [markdown]
# #### Save model

# %% [markdown]
# #### Logistic regression with hyperparameter tuning

# %%
import math
#Taking different set of values for C where C = 1/λ
parameters={'C':[10**-6,10**-5,10**-4, 10**-2, 10**0, 10**2, 10**3]}

#For plotting
log_c = list(map(lambda x : float(math.log(x)),parameters['C']))

#Using sklearn's LogisticRegression classifier with L2- norm
clf_log = LogisticRegression(penalty='l2') 

#Hyperparameter tuning with 5 fold CV using grid search
clf_2 = GridSearchCV(clf_log, parameters, cv=5,scoring='neg_log_loss',return_train_score =True)
clf_2.fit(X_train, y_train)

train_loss= clf_2.cv_results_['mean_train_score']
cv_loss = clf_2.cv_results_['mean_test_score'] 
#A function defined for plotting cv and trian errors 
#plt.errors(k=log_c,train=train_loss,cv=cv_loss)
plt.plot(log_c, train_loss, color="blue",  label="Training loss")
plt.plot(log_c, cv_loss, color="red",  label="Cv loss")
plt.legend(loc="best")

# %%
clf_2 = clf_2.best_estimator_
#Trainig the model with the best value of C
clf_2.fit(X_train, y_train)

# %%
train_fpr, train_tpr, thresholds = roc_curve(y_train,clf_2.predict_proba(X_train)[:,1]) #false positive rate, true positive rate, clf= classifier
test_fpr, test_tpr, thresholds = roc_curve(y_test, clf_2.predict_proba(X_test)[:,1])

# %%
from sklearn import metrics
auc = roc_curve(y_test, clf_2.predict_proba(X_test)[:,1])
auc_train = round(metrics.auc(train_fpr, train_tpr),2)
auc_test = round(metrics.auc(test_fpr, test_tpr),2)

# %%
#Plotting AUC  

plt.plot(train_fpr, train_tpr, label="train AUC= "+ str(auc_train)) 
plt.plot(test_fpr, test_tpr, label="test AUC= "+ str(auc_test)) 
plt.legend() 
plt.xlabel("FPR") 
plt.ylabel("TPR") 
plt.title("ROC for Train and Test data with best_fit") 
plt.grid()
plt.savefig('ROC-logreg1.png', dpi=100, bbox_inches = "tight")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px"> On looking at test-AUC we can understand that for a new query point there is 83% of the chance that the model can able to predict its original value.
#     </p>

# %% [markdown]
# #### Parameter estimates

# %%
clf_2.intercept_

# %%
clf_2.coef_

# %%
clf.intercept_ == clf_2.intercept_

# %%
clf.coef_ == clf_2.coef_

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px"> Clf and clf2 are the same intercept and coeficient values.
#     </p>

# %%
df_dummy_1.columns

# %%
df_dummy_1.columns.values

# %%
independent_var = df_dummy_1.drop('left',axis=1)

# %%
independent_var.columns.values

# %%
feature_name = independent_var.columns.values

# %%
summary_table = pd.DataFrame(columns=['Feature Name'], data = feature_name)
summary_table['Coefficient'] = np.transpose(clf.coef_)

summary_table

# %%
summary_table.index = summary_table.index + 1

summary_table.loc[0] = ['Intercept', clf.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table

# %% [markdown]
# #### Interpreting the coefficient

# %%
summary_table['Odds_ratio'] = np.exp(summary_table.Coefficient)
summary_table

# %%
summary_table_1 = summary_table.drop([0],axis=0)
summary_table_1 = summary_table_1[(summary_table_1['Odds_ratio']>=1)&(summary_table_1['Coefficient']>=0)].sort_values('Odds_ratio', ascending = False)
summary_table_1

# %%
blankIndex=[''] * len(summary_table_1)
summary_table_1.index=blankIndex
summary_table_1

# %%
ticks=np.arange(8)
labels=summary_table_1['Feature Name']

# %%
plt.figure(figsize=(15,10))
summary_table_1.sort_values('Odds_ratio', ascending = False).plot(kind='bar')
plt.xticks(ticks,labels, rotation='vertical')
plt.savefig('log_reg1.png', dpi=100, bbox_inches = "tight")

# %%
sns.kdeplot(x='Odds_ratio', y='Coefficient', data=summary_table_1, logistic=True, ci=None)
plt.title('Odds ratio vs coefficient')
plt.savefig('odds-ratio-logreg1.png', dpi=100, bbox_inches = "tight")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b style = "font-family: Arial; font-size: 16px">Interpretation has been corrected:</b>
#     <ol style = "text-align:justify; font-family: Verdana; font-size: 14px">Looking in the features' there a group in the top with coefficient all above 0 (positive) and odds ratio above 1. It can be said that:
#         <li><b>Salary low </b> 2 times will left the company because of low salary.
#         <li><b>Tenure</b>1 times will left the company because of employee tenure (with more staying with tenure above 6 years as previous graph).
#         <li><b>Dept sales</b>1 times will left the company because of in sales department (as in pareto).
#         <li><b>Dept hr</b>1 times will left the company because of in hr department (as in pareto).
#         <li><b>Salary medium</b>1 times will left the company because of in hr department (as in pareto)
#         <li>Up to average monthly hours.
#     </ol>
#     <p style = "text-align:justify; font-family: Verdana; font-size: 14px"> The other group's coeficient below 0 and with odd ratio below 1. which implies no difference.</p>
#     <p style = "text-align:justify; font-family: Verdana; font-size: 14px"> Intercept or the bias calibrates the model. Intercept prevents going off the mark with precisely that value </p>
#     <p style = "text-align:justify; font-family: Verdana; font-size: 14px"> After omitting the results change than the above interpretation as different from figure</p>
# </div>

# %% [markdown]
# #### Prediction and evaluation

# %%
y_pred_2 = clf_2.predict(X_test)

# %%
# Create classification report for logistic regression model
target_names = ['Predicted would not leave', 'Predicted would leave']
print(classification_report(y_test, y_pred_2, target_names=target_names))
print(confusion_matrix(y_test,y_pred_2))
print('\n')
print(accuracy_score(y_test,y_pred_2))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The model with hyperparameter tunig with 5 fold CV yield the same results using grid search.
#     </p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><ol style = "font-family:Verdana; font-size:14px">
#     <li> Machine Learning  Engineer, prefer models with higher accuracy, so normally go for standardization.
#     <li> Econometricians and Statisticians, more about interpretable models about the underlying reasons
#     <li> Standardization more of the norm, create more than 1 models, 1 with standardization features and 1 without them.</ol>
# </div>

# %% [markdown]
# ## Model 2: Decision Tree (1)

# %% [markdown]
# #### Encode the categorical variables

# %%
#Encode the categorical variables
df_dummy_2 = pd.get_dummies(df_1)

# %% [markdown]
# ### Split, Train and Test Data

# %%
# Isolate the outcome variable
y = df_dummy_2['left']
# Select the features
X = df_dummy_2.drop('left', axis=1)

# Display the first few rows of `X`
X.head()

# %% [markdown]
# #### Training model

# %%
# Create test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=0)

# Create train & validate data
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.25, stratify=y_train, random_state=0)

# %%
# Instantiate model
tree = DecisionTreeClassifier(random_state=0)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth':[3, 6, 9, None],
             'min_samples_leaf': [3, 5, 7],
             'min_samples_split': [3, 4, 5]
             }

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
tree1 = GridSearchCV(tree, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
tree1.fit(X_train, y_train) #5.57s

# %%
# Check best AUC score on CV
tree1.best_score_

# %%
def make_results(model_name:str, model_object, metric:str):
    '''
    Arguments:
        model_name (string): what you want the model to be called in the output table
        model_object: a fit GridSearchCV object
        metric (string): precision, recall, f1, accuracy, or auc
  
    Returns a pandas df with the F1, recall, precision, accuracy, and auc scores
    for the model with the best mean 'metric' score across all validation folds.  
    '''

    # Create dictionary that maps input metric to actual metric name in GridSearchCV
    metric_dict = {'auc': 'mean_test_roc_auc',
                 'precision': 'mean_test_precision',
                 'recall': 'mean_test_recall',
                 'f1': 'mean_test_f1',
                 'accuracy': 'mean_test_accuracy',
                 }

    # Get all the results from the CV and put them in a df
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(metric) score
    best_estimator_results = cv_results.iloc[cv_results[metric_dict[metric]].idxmax(), :]

    # Extract Accuracy, precision, recall, and f1 score from that row
    auc = best_estimator_results.mean_test_roc_auc
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy
  
    # Create table of results
    table = pd.DataFrame()
    table = table.append({'Model': model_name,
                        'AUC': auc,
                        'Precision': precision,
                        'Recall': recall,
                        'F1': f1,
                        'Accuracy': accuracy,
                        },
                        ignore_index=True
                       )
  
    return table

# %%
# Get all CV scores
tree1_cv_results = make_results('decision tree cv', tree1, 'auc')
tree1_cv_results

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The classification report above shows that the decision tree results is better than the logistic regression model achieved a precision of 97% compare to 79%, recall of 92% compare to 83%, f1-score of 94% to 70% (all weighted averages), and accuracy of 98% compare to 83%, and AUC 97% from decision tree to 83% of logistic regression. The AUC shows a strong model.
#     </p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><ol style = "font-family:Verdana; font-size:14px">
# Decision trees can be vulnerable to overfitting, and random forests avoid overfitting by incorporating multiple trees to make predictions. You could construct a random forest model next. The model may come up too good as we may required to conduct feature engineering.
# </div>

# %%
def conf_matrix_plot(model, x_data, y_data):
    '''
    Accepts as argument model object, X data (test or validate), and y data (test or validate). 
    Returns a plot of confusion matrix for predictions on y data.
    ''' 
  
    model_pred = model.predict(x_data)
    cm = confusion_matrix(y_data, model_pred, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=model.classes_)
  
    disp.plot(values_format='')
    plt.show()

# %%
# Generate confusion matrix
conf_matrix_plot(tree1, X_test, y_test)

# %%
# Plot the tree
plt.figure(figsize=(85,20))
plot_tree(tree1.best_estimator_, max_depth=6, fontsize=14, feature_names=X.columns, 
          class_names={0:'stayed', 1:'left'}, filled=True)
plt.savefig('tree1.png', dpi=400, bbox_inches = "tight")
plt.show()

# %%
#tree1_importances = pd.DataFrame(tree1.best_estimator_.feature_importances_, columns=X.columns)
tree1_importances = pd.DataFrame(tree1.best_estimator_.feature_importances_, columns=['gini_importance'], index=X.columns)
tree1_importances = tree1_importances.sort_values(by='gini_importance', ascending=False)

# Only extract the features with importances > 0
tree1_importances = tree1_importances[tree1_importances['gini_importance'] != 0]
tree1_importances

# %%
sns.barplot(data=tree1_importances, x="gini_importance", y=tree1_importances.index, orient='h')
plt.title("Decision Tree: Feature Importances for Employee Leaving", fontsize=12)
plt.ylabel("Feature")
plt.xlabel("Importance")
plt.savefig('tree1-importance.png', dpi=400, bbox_inches = "tight")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px"> Compare to the logistic regression, the decision tree strong features from the stronger is the satisfaction level, last evaluation, number project, tenure, average monthly hours, salary and technical department. This result is very different compare the odds ratio of the logistic regression.
#     </p>

# %% [markdown]
# ## Model 3: Random Forrest (1)

# %%
# Instantiate model
rf = RandomForestClassifier(random_state=0)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth': [2,4, None], 
             'max_features': [1.0],
             'max_samples': [0.7, 1.0],
             'min_samples_leaf': [3,5,7],
             'min_samples_split': [3,4,6],
             'n_estimators': [300, 500],
             }  

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
rf1 = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
rf1.fit(X_tr, y_tr) # --> Wall time: ~26:19s

# %%
# Define a path to the folder where you want to save the model
path = '/kaggle/working/'

# %%
def write_pickle(path, model_object, save_as:str):
    '''
    In: 
        path:         path of folder where you want to save the pickle
        model_object: a model you want to pickle
        save_as:      filename for how you want to save the model

    Out: A call to pickle the model in the folder indicated
    '''    

    with open(path + save_as + '.pickle', 'wb') as to_write:
        pickle.dump(model_object, to_write)

# %%
def read_pickle(path, saved_model_name:str):
    '''
    In: 
        path:             path to folder where you want to read from
        saved_model_name: filename of pickled model you want to read in

    Out: 
        model: the pickled model 
    '''
    with open(path + saved_model_name + '.pickle', 'rb') as to_read:
        model = pickle.load(to_read)

    return model

# %%
# Write pickle
write_pickle(path, rf1, 'hr_rf1')

# %%
# Read pickle
rf1 = read_pickle(path, 'hr_rf1')

# %%
# Check best AUC score on CV
rf1.best_score_

# %%
# Get all CV scores
rf1_cv_results = make_results('random forest cv', rf1, 'auc')
print(tree1_cv_results)
print(rf1_cv_results)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The AUC from the random forest is 98% which higher than of deciion tree, while precision, recall and accuracy below decision tree.
#     </p>

# %%
def get_scores(model_name:str, model, X_test_data, y_test_data):
    '''
    Generate a table of test scores.

    In: 
        model_name (string):  How you want your model to be named in the output table
        model:                A fit GridSearchCV object
        X_test_data:          numpy array of X_test data
        y_test_data:          numpy array of y_test data

    Out: pandas df of precision, recall, f1, accuracy, and AUC scores for your model
    '''

    preds = model.best_estimator_.predict(X_test_data)

    auc = round(roc_auc_score(y_test_data, preds), 3)
    accuracy = round(accuracy_score(y_test_data, preds), 3)
    precision = round(precision_score(y_test_data, preds), 3)
    recall = round(recall_score(y_test_data, preds), 3)
    f1 = round(f1_score(y_test_data, preds), 3)

    table = pd.DataFrame({'model': [model_name],
                        'AUC': [auc],
                        'precision': [precision], 
                        'recall': [recall],
                        'f1': [f1],
                        'accuracy': [accuracy]
                        })
  
    return table

# %%
# Get the results on validation set for both models
tree1_val_results = get_scores('decision tree1 val', tree1, X_val, y_val)
rf1_val_results = get_scores('random forest1 val', rf1, X_val, y_val)

# Concatenate validation scores into table
all_val_results1 = [tree1_val_results, rf1_val_results]
all_val_results1 = pd.concat(all_val_results1).sort_values(by='AUC', ascending=False)
all_val_results1

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">On the validation, the results are slightly the same for AUC and recall, for precision, f1 and accuracy are lower than the decision tree.
#     </p>

# %%
# Get predictions on test data
rf1_test_scores = get_scores('random forest1 test', rf1, X_test, y_test)
rf1_test_scores

# %%
# Generate array of values for confusion matrix
preds = rf1.best_estimator_.predict(X_test)
cm = confusion_matrix(y_test, preds, labels=rf1.classes_)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=rf1.classes_)
disp.plot()

# %%
# Get feature importances
feat_impt = rf1.best_estimator_.feature_importances_

# Get indices of top 10 features
ind = np.argpartition(rf1.best_estimator_.feature_importances_, -10)[-10:]

# Get column labels of top 10 features 
feat = X.columns[ind]

# Filter `feat_impt` to consist of top 10 feature importances
feat_impt = feat_impt[ind]

y_df = pd.DataFrame({"Feature":feat,"Importance":feat_impt})
y_sort_df = y_df.sort_values("Importance")
fig = plt.figure()
ax1 = fig.add_subplot(111)

y_sort_df.plot(kind='barh',ax=ax1,x="Feature",y="Importance")

ax1.set_title("Random Forest: Feature Importances for Employee Leaving", fontsize=12)
ax1.set_ylabel("Feature")
ax1.set_xlabel("Importance")
plt.savefig('rf1-importance.png', dpi=400, bbox_inches = "tight")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Random forest has 10 feature importance variables, compare 7 for decision tree with satisfaction level on the top.
# </p>

# %% [markdown]
# ## Model 4: XGBoost (1)

# %%
# 1. Instantiate the XGBoost classifier
xgb = XGBClassifier(objective='binary:logistic', random_state=0)  

# 2. Create a dictionary of hyperparameters to tune
cv_params = {'max_depth': [4,8,12], 
             'min_child_weight': [3, 5],
             'learning_rate': [0.01, 0.1],
             'n_estimators': [300, 500]
             }   

# 3. Define a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1'}

# 4. Instantiate the GridSearchCV object
xgb_cv1 = GridSearchCV(xgb, cv_params, scoring=scoring, cv=4, refit='f1')

# %%
# %%time
# # avg. 15 min 37s
xgb_cv1.fit(X_train, y_train)

# %%
write_pickle(path, xgb_cv1, 'hr_xgb_cv1')

# %%
xgb_cv1 = read_pickle(path, 'hr_xgb_cv1')

# %%
# Examine best score
xgb_cv1.best_score_

# %%
# Examine best parameters
xgb_cv1.best_params_

# %%
# Call 'make_results()' on the GridSearch object
#xgb_cv1_results = make_results('XGBoost 1: f1', xgb_cv1, 'f1')
#print(xgb_cv1_results)

# %%
# Get scores on test data
preds = xgb_cv1.best_estimator_.predict(X_test)

# %%
# Get scores on test data
xgb_cv1_test_scores = get_scores('XGBoost 1: test',xgb_cv1, X_test, y_test)
xgb_cv1_test_scores

# %%
# Generate array of values for confusion matrix
cm = confusion_matrix(y_test, preds, labels=xgb_cv1.classes_)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=xgb_cv1.classes_)
disp.plot();

# %%
plot_importance(xgb_cv1.best_estimator_, max_num_features=10);
plt.savefig('xgboost1-importance.png', dpi=400, bbox_inches = "tight")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">XGBoost and Random forest has 10 feature importance variables, compare 7 for decision tree with average monthly hours on the top. We can see that the variables and its order are different among models.
# </p>

# %% [markdown]
# ## Add : KMeans (1) - Cluster
#
# #### Scaled data

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
# Scale the data
X_scaled = StandardScaler().fit_transform(X)

# %%
# Fit K-means and evaluate inertia for different values of k.

### YOUR CODE HERE ###

num_clusters = [i for i in range(2, 20)]

def kmeans_inertia(num_clusters, x_vals):
    """
    Accepts as arguments list of ints and data array. 
    Fits a KMeans model where k = each value in the list of ints. 
    Returns each k-value's inertia appended to a list.
    """
    inertia = []
    for num in num_clusters:
        kms = KMeans(n_clusters=num, random_state=0)
        kms.fit(x_vals)
        inertia.append(kms.inertia_)

    return inertia

# %%
# Return a list of inertia for k=2 to 20.

### YOUR CODE HERE ###

inertia = kmeans_inertia(num_clusters, X_scaled)
inertia

# %% [markdown]
# #### Elbow Plot

# %%
# Create an elbow plot
plt.figure(figsize=(12,6))
plot = sns.lineplot(x=num_clusters, y=inertia, marker = 'o')
plot.set_xlabel("Number of clusters")
plot.set_ylabel("Inertia")

# %% [markdown]
# #### Evaluate silhouette score
#
# <div style = "font-family: Arial; font-size: 16px">
# Unlike inertia, silhouette score doesn't have its own attribute that can be called on the model object. To get a silhouette score, we have to use the `silhouette_score()` function that we imported from `sklearn.metrics`. You must pass to it two required parameters: your training data and their assigned cluster labels. Let's see what this looks like for the `kmeans~8` model we created earlier.</div>

# %%
# Instantiate model
kmeans15 = KMeans(n_clusters=15, random_state=0)
kmeans15.fit(X_scaled)

# %%
# Get silhouette score for kmeans3 model
kmeans15_sil_score = silhouette_score(X_scaled, kmeans15.labels_)
kmeans15_sil_score

# %%
def kmeans_sil(num_clusters, x_vals):
    '''
    Fits a KMeans model for different values of k.
    Calculates a silhouette score for each k value

    Args:
        num_clusters: (list of ints)  - The different k values to try
        x_vals:       (array)         - The training data

    Returns: 
        sil_score:    (list)          - A list of silhouette scores, one for each \
                                      value of k
    '''
  
    sil_score = []
    for num in num_clusters:
        kms = KMeans(n_clusters=num, random_state=42)
        kms.fit(x_vals)
        sil_score.append(silhouette_score(x_vals, kms.labels_))
    
    return sil_score

# %%
# Calculate silhouette scores for k=2-20
sil_score = kmeans_sil(num_clusters, X_scaled)
sil_score

# %%
# Create a line plot of silhouette scores 
plot = sns.lineplot(x=num_clusters, y=sil_score, marker = 'o')
plot.set_xlabel("# of clusters")
plot.set_ylabel("Silhouette Score")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">It looks that This plot indicates that the silhouette score is not closest to 1 but the highest is when our data is partitioned into sixteen clusters. It confirms what we saw in the inertia analysis different, where we noticed an elbow where _k_=9.
# </p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><ol style = "font-family:Verdana; font-size:14px">
# The high evaluation scores, may rise doubt. Unrealistic score may be resulted due to <b>data leakage</b> as when you train the model using data it appears in the test data or it is not the expected data to give when the model actually deployed. This can caused unreplicated in production.
# <br><br>
# Scenario of possibilities to understand this model is required. based on the data of four models with all data provided yield AUC 83% logistic regression, around 95% for decsion tree, random forest and xgboost. In this case, as aformentioned, seeing in experience and observe the company, the average hours is taken into account as each employee each month work hours may differ, hence the average is selected. Also, we may found that there are employees who has been terminated before end of month thus the average hours monthly may not reflect a month of work as working fewer hours that may skewed the data. This is shown that there are hours below 166.67 hours/month. In addition, not all employees submit their satisfaction levels report or this may apply to the employee evaluation. There is cut off of both report and the evaluation being conducted.
#
# <br><br>
# Next, feature engineering will address this likelihood of data leakage.
# </div>

# %% [markdown]
# ### Feature Engineering
#
# <div style = "font-family: Arial; font-size: 16px">
#     If we look the graph between satisfaction level, last evaluation and average work monthly in our analyze phase, there are people with 245-315 hours/month, satisfaction level below 0.2 and with their last evaluation results 0.75 to 0.95 that we look further and can be dropped. Moreover, creating a new feature to capture good_performance and overworked

# %%
df_1.head()

# %%
df_1.describe().transpose()

# %% [markdown]
# #### Drop the data with high evaluation, high working hours and low satisfaction level

# %%
df_1[(df_1['last_evaluation']>=0.7) & (df_1['satisfaction_level'] <0.2) & (df_1['average_monthly_hours'] >=240)].value_counts()

# %%
data_drop = df_1[(df_1['last_evaluation']>=0.7) & (df_1['satisfaction_level'] <0.2) & (df_1['average_monthly_hours'] >=240)]

# %%
df_3=df_1.drop(data_drop.index,axis=0)

# %%
df_3.describe().transpose()

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Create scatterplot of `average_monthly_hours` versus `satisfaction_level`, comparing employees who stayed versus those who left
plt.figure(figsize=(16, 9))
sns.scatterplot(data=df_3, x='average_monthly_hours', y='last_evaluation', hue='left', alpha=0.4)
plt.axvline(x=166.67, color='red', label='166.67 hrs./mo.', ls='--')
plt.legend(labels=['166.67 hrs./mo.', 'stayed', 'left'])
plt.title('Monthly hours by last evaluation', fontsize='14')

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Create scatterplot of `satisfaction level versus `satisfactionlevel`, comparing employees who stayed versus those who left
plt.figure(figsize=(16, 9))
sns.scatterplot(data=df_3, x='last_evaluation', y='satisfaction_level', hue='left', alpha=0.8)
plt.title('Last evaluation by satisfaction level', fontsize='14');

# %%
# Create a plot as needed 
### YOUR CODE HERE ###

# Create scatterplot of `average_monthly_hours` versus `satisfaction_level`, comparing employees who stayed versus those who left
plt.figure(figsize=(16, 9))
sns.scatterplot(data=df_3, x='average_monthly_hours', y='satisfaction_level', hue='left', alpha=0.4)
plt.axvline(x=166.67, color='red', label='166.67 hrs./mo.', ls='--')
plt.legend(labels=['166.67 hrs./mo.', 'stayed', 'left'])
plt.title('Monthly hours by last evaluation', fontsize='14')

# %% [markdown]
# #### Overworked

# %%
# Create `overworked` column. For now, it's identical to average monthly hours.
df_3['overworked'] = df_3['average_monthly_hours']

# Inspect max and min average monthly hours values
print('Max hours:', df_3['overworked'].max())
print('Min hours:', df_3['overworked'].min())

# %%
# Define `overworked` as working > 175 hrs/week
df_3['overworked'] = (df_3['overworked'] > 170).astype(int)

# Display first few rows of new column
df_3['overworked'].head()

# %%
# Drop the `average_monthly_hours` column
df_3 = df_3.drop('average_monthly_hours', axis=1)

# Display first few rows of resulting dataframe
df_3.head()

# %% [markdown]
# #### Good performance

# %%
# Create `good performance` column. For now, it's identical to average monthly hours.
df_3['good_performance'] = df_3['last_evaluation']
# Inspect max and min good performance hours values
print('Max hours:', df_3['good_performance'].max())
print('Min hours:', df_3['good_performance'].min())

# %%
# Define `good performance` as working > 175 hrs/week
df_3['good_performance'] = (df_3['good_performance'] >= 0.6).astype(int)

# Display first few rows of new column
df_3['good_performance'].head()

# %%
# Drop the `last_evaluation` column
df_3 = df_3.drop('last_evaluation', axis=1)

# Display first few rows of resulting dataframe
df_3.head()

# %% [markdown]
# #### Creating dummy

# %%
# Dummy the categorical variables as needed and save resulting dataframe in a new variable
df_dummy_3 = pd.get_dummies(df_3, prefix=['salary', 'dept'], columns = ['salary', 'department'], drop_first=False)

# Display the new dataframe
df_dummy_3.head()

# %%
df.to_csv('/kaggle/working/Proj004-P02-ML-Models-HR-Analytics-20230505-dummy-3.csv', index=False)

# %% [markdown]
# ## Model 5: Logistic regression (2)

# %%
x1 = df_dummy_3['satisfaction_level'] 
x2 = df_dummy_3['good_performance']
x3 = df_dummy_3['number_project']
x4 = df_dummy_3['overworked']
x5 = df_dummy_3['tenure']
x6 = df_dummy_3['promotion_last_5years']
y = df_dummy_3['left']

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10), sharey=True)
fig.suptitle('Left')

# Satisfaction level
sns.regplot(ax=axes[0,0], x=x1, y=y, data=df_dummy_3, logistic=True, ci=None)
axes[0,0].set_title('Satisfaction level')

# Last evaluation
sns.regplot(ax=axes[0,1], x=x2, y=y, data=df_dummy_3, logistic=True, ci=None)
axes[0,1].set_title('Good performance')

# Number of project
sns.regplot(ax=axes[0,2], x=x3, y=y, data=df_dummy_3, logistic=True, ci=None)
axes[0,2].set_title('Number of project')

# Satisfaction level
sns.regplot(ax=axes[1,0], x=x4, y=y, data=df_dummy_3, logistic=True, ci=None)
axes[1,0].set_title('Overworked')

# Last evaluation
sns.regplot(ax=axes[1,1], x=x5, y=y, data=df_dummy_3, logistic=True, ci=None)
axes[1,1].set_title('Tenure')

# Number of project
sns.regplot(ax=axes[1,2], x=x6, y=y, data=df_dummy_3, logistic=True, ci=None)
axes[1,2].set_title('Promotion last 5 years')

plt.savefig('reg-six-plots_2')

# %% [markdown]
# ### Split, train and test data

# %%
X = df_dummy_3.drop('left',axis=1)
y = df_dummy_3['left']

# %% [markdown]
# #### Training model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
clf_3 = LogisticRegression()
clf_3 = clf_3.fit(X_train,y_train)

# %% [markdown]
# #### Parameter estimates

# %%
clf_3.intercept_

# %%
clf_3.coef_

# %% [markdown]
# #### Prediction and evaluation

# %%
y_pred = clf_3.predict(X_test)

# %% [markdown]
# #### Confussion matrix

# %%
# Compute values for confusion matrix
log_cm = confusion_matrix(y_test, y_pred, labels=clf_3.classes_)

# Create display of confusion matrix
log_disp = ConfusionMatrixDisplay(confusion_matrix=log_cm, display_labels=clf_3.classes_)

# Plot confusion matrix
log_disp.plot()

# Display plot
plt.show()

# %%
df_dummy_3['left'].value_counts(normalize=True)

# %%
# Create classification report for logistic regression model
target_names = ['Predicted would not leave', 'Predicted would leave']
print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test,y_pred))
print('\n')
print(accuracy_score(y_test,y_pred))

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">All the parameters of the result increase after feature engineering, Accuracy from 83% to 89%
# </p>

# %% [markdown]
# #### Save model

# %% [markdown]
# #### AUC result

# %%
train_fpr, train_tpr, thresholds = roc_curve(y_train,clf_3.predict_proba(X_train)[:,1]) #false positive rate, true positive rate, clf= classifier
test_fpr, test_tpr, thresholds = roc_curve(y_test, clf_3.predict_proba(X_test)[:,1])

# %%
from sklearn import metrics
auc = roc_curve(y_test, clf_3.predict_proba(X_test)[:,1])
auc_train = round(metrics.auc(train_fpr, train_tpr),2)
auc_test = round(metrics.auc(test_fpr, test_tpr),2)

# %%
#Plotting AUC  

plt.plot(train_fpr, train_tpr, label="train AUC= "+ str(auc_train)) 
plt.plot(test_fpr, test_tpr, label="test AUC= "+ str(auc_test)) 
plt.legend() 
plt.xlabel("FPR") 
plt.ylabel("TPR") 
plt.title("ROC for Train and Test data") 
plt.grid()
plt.savefig('ROC-logreg2.png', dpi=400, bbox_inches = "tight")
plt.show()

# %% [markdown]
# #### Logistic regression with hyperparamter tuning

# %%
import math
#Taking different set of values for C where C = 1/λ
parameters={'C':[10**-6,10**-5,10**-4, 10**-2, 10**0, 10**2, 10**3]}

#For plotting
log_c = list(map(lambda x : float(math.log(x)),parameters['C']))

#Using sklearn's LogisticRegression classifier with L2- norm
clf_log = LogisticRegression(penalty='l2') 

#Hyperparameter tuning with 5 fold CV using grid search
clf_4 = GridSearchCV(clf_log, parameters, cv=5,scoring='neg_log_loss',return_train_score =True)
clf_4.fit(X_train, y_train)

train_loss= clf_4.cv_results_['mean_train_score']
cv_loss = clf_4.cv_results_['mean_test_score'] 
#A function defined for plotting cv and trian errors 
#plt.errors(k=log_c,train=train_loss,cv=cv_loss)
plt.plot(log_c, train_loss, color="blue",  label="Training loss")
plt.plot(log_c, cv_loss, color="red",  label="Cv loss")
plt.legend(loc="best")

# %%
clf_4 = clf_4.best_estimator_
#Trainig the model with the best value of C
clf_4.fit(X_train, y_train)

# %%
train_fpr, train_tpr, thresholds = roc_curve(y_train,clf_4.predict_proba(X_train)[:,1]) #false positive rate, true positive rate, clf= classifier
test_fpr, test_tpr, thresholds = roc_curve(y_test, clf_4.predict_proba(X_test)[:,1])

# %%
auc = roc_curve(y_test, clf_4.predict_proba(X_test)[:,1])
auc_train = round(metrics.auc(train_fpr, train_tpr),2)
auc_test = round(metrics.auc(test_fpr, test_tpr),2)

# %%
#Plotting AUC  

plt.plot(train_fpr, train_tpr, label="train AUC= "+ str(auc_train)) 
plt.plot(test_fpr, test_tpr, label="test AUC= "+ str(auc_test)) 
plt.legend() 
plt.xlabel("FPR") 
plt.ylabel("TPR") 
plt.title("ROC for Train and Test data with best_fit") 
plt.grid() 
plt.savefig('ROC-logreg2.png', dpi=400, bbox_inches = "tight")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Eventhough we have an increase from other parameters, the AUC result is 81% which is still similar with before feature engineering result.
# </p>

# %% [markdown]
# #### Odds ratio summary table

# %%
df_dummy_3.columns

# %%
df_dummy_3.columns.values

# %%
independent_var_2 = df_dummy_3.drop('left',axis=1)

# %%
feature_name_2 = independent_var_2.columns.values

# %%
summary_table_2 = pd.DataFrame(columns=['Feature Name'], data = feature_name_2)
summary_table_2['Coefficient'] = np.transpose(clf_3.coef_)

summary_table_2

# %%
summary_table_2.index = summary_table_2.index + 1

summary_table_2.loc[0] = ['Intercept', clf_3.intercept_[0]]
summary_table_2 = summary_table.sort_index()
summary_table_2

# %%
summary_table_2['Odds_ratio'] = np.exp(summary_table_2.Coefficient)
summary_table_2

# %%
summary_table_1 = summary_table.drop([0],axis=0)
summary_table_1 = summary_table_1[(summary_table_1['Odds_ratio']>=1)&(summary_table_1['Coefficient']>=0)].sort_values('Odds_ratio', ascending = False)
summary_table_1

# %%
blankIndex=[''] * len(summary_table_1)
summary_table_1.index=blankIndex
summary_table_1

# %%
ticks=np.arange(8)
labels=summary_table_1['Feature Name']

# %%
plt.figure(figsize=(15,10))
summary_table_1.sort_values('Odds_ratio', ascending = False).plot(kind='bar')
plt.xticks(ticks,labels, rotation='vertical')
plt.savefig('log_reg2.png', dpi=400, bbox_inches = "tight")

# %%
sns.kdeplot(x='Odds_ratio', y='Coefficient', data=summary_table_2, logistic=True, ci=None)
plt.title('Odds ratio vs coefficient')
plt.savefig('odds-ratio-logreg2.png')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">All the features variable's of odds ratio has changed to above 1. The variables in top still salary low but others have changed order compare before feature engineering.
# </p>

# %% [markdown]
# ## Model 6: Decision tree (2)

# %% [markdown]
# #### Split, train and test data

# %%
df_dummy_4 = df_dummy_3.copy()

# Isolate the outcome variable
y = df_dummy_4['left']
# Select the features
X = df_dummy_4.drop('left', axis=1)

# Display the first few rows of `X`
X.head()

# %%
# Create test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=0)

# Create train & validate data
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.25, stratify=y_train, random_state=0)

# %%
# Instantiate model
tree = DecisionTreeClassifier(random_state=0)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth':[3, 6, 9, None],
             'min_samples_leaf': [3, 5, 7],
             'min_samples_split': [3, 4, 5]
             }

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
tree2 = GridSearchCV(tree, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
tree2.fit(X_tr, y_tr) #~4.23 s

# %%
# Check best params
tree2.best_params_

# %%
# Check best AUC score on CV
tree2.best_score_

# %%
# Get all CV scores
tree2_cv_results = make_results('decision tree2 cv', tree2, 'auc')
tree2_cv_results

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px"> Some of the other scores fell. That's to be expected given fewer features were taken into account in this round of the model. Still, the scores are very good.
# </p>

# %%
def conf_matrix_plot(model, x_data, y_data):
    '''
    Accepts as argument model object, X data (test or validate), and y data (test or validate). 
    Returns a plot of confusion matrix for predictions on y data.
    ''' 
  
    model_pred = model.predict(x_data)
    cm = confusion_matrix(y_data, model_pred, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=model.classes_)
  
    disp.plot(values_format='')
    plt.show()

# %%
# Generate confusion matrix
conf_matrix_plot(tree2, X_test, y_test)

# %%
# Plot the tree
plt.figure(figsize=(85,20))
plot_tree(tree2.best_estimator_, max_depth=6, fontsize=14, feature_names=X.columns, 
          class_names={0:'stayed', 1:'left'}, filled=True)
plt.savefig('tree2.png', dpi=400, bbox_inches = "tight")
plt.show()

# %%
#tree2_importances = pd.DataFrame(tree2.best_estimator_.feature_importances_, columns=X.columns)
tree2_importances = pd.DataFrame(tree2.best_estimator_.feature_importances_, columns=['gini_importance'], index=X.columns)
tree2_importances = tree2_importances.sort_values(by='gini_importance', ascending=False)

# Only extract the features with importances > 0
tree2_importances = tree2_importances[tree2_importances['gini_importance'] != 0]
tree2_importances

# %%
sns.barplot(data=tree2_importances, x="gini_importance", y=tree2_importances.index, orient='h')
plt.title("Decision Tree: Feature Importances for Employee Leaving", fontsize=12)
plt.ylabel("Feature")
plt.xlabel("Importance")
plt.savefig('tree2-importance.png', dpi=400, bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Model 7: Random forest (2)

# %%
# Instantiate model
rf = RandomForestClassifier(random_state=0)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth': [2,4, None], 
             'max_features': [1.0],
             'max_samples': [0.7, 1.0],
             'min_samples_leaf': [3,5,7],
             'min_samples_split': [3,4,6],
             'n_estimators': [300, 500],
             }  

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
rf2 = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
rf2.fit(X_tr, y_tr) # --> Wall time: 20min 30s

# %%
# Write pickle
write_pickle(path, rf2, 'hr_rf2')

# %%
# Read in pickle
rf2 = read_pickle(path, 'hr_rf2')

# %%
# Check best params
rf2.best_params_

# %%
# Check best AUC score on CV
rf2.best_score_

# %%
# Get all CV scores
rf2_cv_results = make_results('random forest2 cv', rf2, 'auc')
print(tree2_cv_results)
print(rf2_cv_results)

# %%
# Collect validation scores 
tree2_val_results = get_scores('decision tree2 val', tree2, X_val, y_val)
rf2_val_results = get_scores('random forest2 val', rf2, X_val, y_val)

# Concatenate validation scores into table
all_val_results2 = [tree2_val_results, rf2_val_results]
all_val_results2 = pd.concat(all_val_results2).sort_values(by='AUC', ascending=False)
all_val_results2

# %%
# Get predictions on test data
rf2_test_scores = get_scores('random forest2 test', rf2, X_test, y_test)
rf2_test_scores

# %%
# Generate array of values for confusion matrix
preds = rf2.best_estimator_.predict(X_test)
cm = confusion_matrix(y_test, preds, labels=rf2.classes_)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=rf2.classes_)
disp.plot()

# %%
# Get feature importances
feat_impt = rf2.best_estimator_.feature_importances_

# Get indices of top 10 features
ind = np.argpartition(rf2.best_estimator_.feature_importances_, -10)[-10:]

# Get column labels of top 10 features 
feat = X.columns[ind]

# Filter `feat_impt` to consist of top 10 feature importances
feat_impt = feat_impt[ind]

y_df = pd.DataFrame({"Feature":feat,"Importance":feat_impt})
y_sort_df = y_df.sort_values("Importance")
fig = plt.figure()
ax1 = fig.add_subplot(111)

y_sort_df.plot(kind='barh',ax=ax1,x="Feature",y="Importance")

ax1.set_title("Random Forest: Feature Importances for Employee Leaving", fontsize=12)
ax1.set_ylabel("Feature")
ax1.set_xlabel("Importance")
plt.savefig('rf2-importance.png', dpi=400, bbox_inches = "tight")
plt.show()

# %% [markdown]
# ## Model 8: XGBoost

# %%
# 1. Instantiate the XGBoost classifier
xgb = XGBClassifier(objective='binary:logistic', random_state=0)  

# 2. Create a dictionary of hyperparameters to tune
cv_params = {'max_depth': [4,8,12], 
             'min_child_weight': [3, 5],
             'learning_rate': [0.01, 0.1],
             'n_estimators': [300, 500]
             }   

# 3. Define a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1'}

# 4. Instantiate the GridSearchCV object
xgb_cv2 = GridSearchCV(xgb, cv_params, scoring=scoring, cv=4, refit='f1')

# %%
# %%time
# # avg. 14 min 39s
xgb_cv2.fit(X_train, y_train)

# %%
write_pickle(path, xgb_cv2, 'hr_xgb_cv2')

# %%
xgb_cv2 = read_pickle(path, 'hr_xgb_cv2')

# %%
# Examine best score
xgb_cv2.best_score_

# %%
# Examine best score
xgb_cv2.best_params_

# %%
# Get scores on test data
preds = xgb_cv2.best_estimator_.predict(X_test)

# %%
# Get scores on test data
xgb_cv2_test_scores = get_scores('XGBoost 1: test',xgb_cv2, X_test, y_test)
xgb_cv2_test_scores

# %%
# Generate array of values for confusion matrix
cm = confusion_matrix(y_test, preds, labels=xgb_cv2.classes_)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=xgb_cv2.classes_)
disp.plot()

# %%
plot_importance(xgb_cv2.best_estimator_, max_num_features=10)
plt.savefig('xgboost2-importance.png', dpi=400, bbox_inches = "tight")

# %% [markdown]
# ## Add : KMeans (2) - Cluster

# %%
# Scale the data
X_scaled = StandardScaler().fit_transform(X)

# %%
# Fit K-means and evaluate inertia for different values of k.

### YOUR CODE HERE ###

num_clusters = [i for i in range(2, 30)]

def kmeans_inertia(num_clusters, x_vals):
    """
    Accepts as arguments list of ints and data array. 
    Fits a KMeans model where k = each value in the list of ints. 
    Returns each k-value's inertia appended to a list.
    """
    inertia = []
    for num in num_clusters:
        kms = KMeans(n_clusters=num, random_state=0)
        kms.fit(x_vals)
        inertia.append(kms.inertia_)

    return inertia

# %%
# Return a list of inertia for k=2 to 20.

### YOUR CODE HERE ###

inertia = kmeans_inertia(num_clusters, X_scaled)
inertia

# %% [markdown]
# #### Elbow plot

# %%
# Create an elbow plot
plt.figure(figsize=(12,6))
plot = sns.lineplot(x=num_clusters, y=inertia, marker = 'o')
plot.set_xlabel("Number of clusters")
plot.set_ylabel("Inertia")

# %% [markdown]
# #### Evaluate silhouette score
#
# <div style = "font-family: Arial; font-size: 16px">
# Unlike inertia, silhouette score doesn't have its own attribute that can be called on the model object. To get a silhouette score, we have to use the `silhouette_score()` function that we imported from `sklearn.metrics`. You must pass to it two required parameters: your training data and their assigned cluster labels. Let's see what this looks like for the `kmeans3` model we created earlier.</div>

# %%
# Instantiate model
kmeans15 = KMeans(n_clusters=15, random_state=0)
kmeans15.fit(X_scaled)

# %%
# Get silhouette score for kmeans3 model
kmeans15_sil_score = silhouette_score(X_scaled, kmeans15.labels_)
kmeans15_sil_score

# %%
def kmeans_sil(num_clusters, x_vals):
    '''
    Fits a KMeans model for different values of k.
    Calculates a silhouette score for each k value

    Args:
        num_clusters: (list of ints)  - The different k values to try
        x_vals:       (array)         - The training data

    Returns: 
        sil_score:    (list)          - A list of silhouette scores, one for each \
                                      value of k
    '''
  
    sil_score = []
    for num in num_clusters:
        kms = KMeans(n_clusters=num, random_state=42)
        kms.fit(x_vals)
        sil_score.append(silhouette_score(x_vals, kms.labels_))
    
    return sil_score

# %%
# Calculate silhouette scores for k=2-20
sil_score = kmeans_sil(num_clusters, X_scaled)
sil_score

# %%
# Create a line plot of silhouette scores 
plot = sns.lineplot(x=num_clusters, y=sil_score, marker = 'o')
plot.set_xlabel("# of clusters")
plot.set_ylabel("Silhouette Score")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">It looks that This plot indicates that the silhouette score is not closest to 1 but the highest is when our data is partitioned into sixteen clusters. It confirms what we saw in the inertia analysis different, where we noticed an elbow where _k_=14.
# </p>

# %% [markdown]
# ## Conclusion
# <hr>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <h3 style = "text-align:center">Table 1.5. Machine Learning Model determine predict people left the company</h3>
#   <tr>
#     <th>Baseline(1)</th>
#     <th>Logistic regression</th>
#     <th>Decision tree</th>
#     <th>Random forest</th>
#     <th>XGboost</th>
#   </tr>
#   <tr style = "text-align:center">
#       <td>AUC</td>
#       <td>83%</td>
#       <td>96%</td>
#       <td>95%</td>
#       <td>95%</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>Precision</td>
#       <td>81%</td>
#       <td>97%</td>
#       <td>92%</td>
#       <td>99%</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>Recall</td>
#       <td>84%</td>
#       <td>92%</td>
#       <td>92%</td>
#       <td>91%</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>f1 score</td>
#       <td>81%</td>
#       <td>94%</td>
#       <td>92%</td>
#       <td>95%</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>Accuracy</td>
#       <td>84%</td>
#       <td>98%</td>
#       <td>97%</td>
#       <td>98%</td>
#   </tr>
#   <tr>
#     <th>Round 2</th>
#     <th>Logistic regression</th>
#     <th>Decision tree</th>
#     <th>Random forest</th>
#     <th>XGboost</th>
#   </tr>
#     <tr style = "text-align:center">
#       <td>AUC</td>
#       <td>80%</td>
#       <td>94%</td>
#       <td>94%</td>
#       <td>93%</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>Precision</td>
#       <td>88%</td>
#       <td>95%</td>
#       <td>92%</td>
#       <td>97%</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>Recall</td>
#       <td>89%</td>
#       <td>89%</td>
#       <td>89%</td>
#       <td>86%</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>f1 score</td>
#       <td>87%</td>
#       <td>92%</td>
#       <td>91%</td>
#       <td>92%</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>Accuracy</td>
#       <td>89%</td>
#       <td>98%</td>
#       <td>98%</td>
#       <td>98%</td>
#   </tr>
#  </table>

# %% [markdown]
# <hr>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <h3 style = "text-align:center">Table 1.6. Machine Learning Model determine predict people left the company</h3>
#   <tr>
#     <th>Baseline(1)</th>
#     <th>Logistic regression</th>
#     <th>Decision tree</th>
#     <th>Random forest</th>
#     <th>XGboost</th>
#   </tr>
#   <tr style = "text-align:center">
#       <td>True positive</td>
#       <td>1958</td>
#       <td>1989</td>
#       <td>1973</td>
#       <td>1996</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>False positive</td>
#       <td>307</td>
#       <td>34</td>
#       <td>33</td>
#       <td>35</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>True Negative</td>
#       <td>66</td>
#       <td>12</td>
#       <td>28</td>
#       <td>5</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>False Negative</td>
#       <td>68</td>
#       <td>364</td>
#       <td>365</td>
#       <td>363</td>
#   </tr>
#   <tr>
#     <th>Round 2</th>
#     <th>Logistic regression</th>
#     <th>Decision tree</th>
#     <th>Random forest</th>
#     <th>XGboost</th>
#   </tr>
#    <tr style = "text-align:center">
#       <td>True positive</td>
#       <td>1964</td>
#       <td>1956</td>
#       <td>1969</td>
#       <td>1979</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>False positive</td>
#       <td>204</td>
#       <td>38</td>
#       <td>39</td>
#       <td>40</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>True Negative</td>
#       <td>39</td>
#       <td>30</td>
#       <td>17</td>
#       <td>7</td>
#   </tr>
#   <tr style = "text-align:center">
#       <td>False Negative</td>
#       <td>78</td>
#       <td>261</td>
#       <td>260</td>
#       <td>259</td>
#   </tr>
#  </table>

# %% [markdown]
# <hr>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#   <h3 style = "text-align:center">Table 2. Machine Learning Model Feature Importance </h3>
#   <tr>
#     <th>Decision Tree (2)</th>
#     <th>Random Forest (2)</th>
#     <th>XG Boost (2)</th>
#   </tr>
#   <tr style = "text-align:center">
#       <td><img style= "margin:auto" src="https://i.imgur.com/geNGequ.png" width = "600"></td>
#       <td><img style= "margin:auto" src="https://i.imgur.com/X3FKKnN.png" width = "600"></td>
#       <td><img style= "margin:auto" src="https://i.imgur.com/QParrbM.png" width = "600"></td>
#   </tr>
#   </table>

# %% [markdown]
# <img style="float:left" src="https://i.imgur.com/wpcEXQC.png" width="50"><div style = "font-family: Arial; font-size: 16px">
#     Execute</div>
#
# ## Conclussion
# <hr>
#
# <div class="alert alert-block alert-success" style="font-family:verdana; font-size:14px">
#
# Logistic Regression
# <br><br>
# The logistic regression model achieved precision of 81%, recall of 84%, f1-score of 81% (all weighted averages), and accuracy of 84%, on the test set.
# <br><br>
# Tree-based Machine Learning
# <br><br>
# After conducting feature engineering, the decision tree model achieved AUC of 96%, precision of97%, recall of 92%, f1-score of 94%, and accuracy of 98%, on the test set. The random forest and xgboost modelslightly underperformed the decision tree model
# <br>
# The models and the feature importances extracted from the models confirm that employees at the company are overworked.
# <br><br>
# To retain employees, the following recommendations could be presented to the stakeholders:
# <br><br>
# <ol>
# <li> Limit the number of projects that employees can work on.
# <li> Promote employees who have great evaluation results and have been for atleast four years, or conduct further investigation about why four-year tenured employees are so dissatisfied.
# <li> Give reward to employees for working longer hours who have brought significant improvements, working collaboratively executing in a project(s) or consider that employee can exchange their overtime with more paid leave of holiday or vacation.
# <li> Ensure that employee has understood the overtime policy, check and if the employee has been given information accordingly.
# <li> Consider proprtionate score on employee's evaluation towards employee who have great impact and team enabler as not due to the amount of works as aligned to point 2.
# <li> Important to have team or department as well in company-wide discussion regarding the work culture. Open consultation from HR to address together with department head or related parties for company's improvement specially for the top talent and medium employee.
# <li> Set a features that can elaborate satisfaction level similar to filter medium and top talent employees (good performance).
# <br><br>
# Next Steps
# <br><br>
# It may be justified to still have some concern about data leakage. It could be prudent to consider how predictions change when `last_evaluation` and employee satisfaction is removed from the data. It's possible that evaluations aren't performed very frequently, in which case it would be useful to be able to predict employee retention without this feature. <b>It's also possible that the evaluation score determines whether an employee leaves or stays, in which case it could be useful to pivot and try to predict performance score. The same could be said for satisfaction score.</b>. After setting the features, it may be more productive to focus on the medium to the top talent employee which possibility has the most satisfied score.
# <br><br>
# We can also see the cluster from this model which k = 15.
# </div>

# %% [markdown]
# <h3 style = "text-align:center">Figure 1. Fishbone Diagram Employee Churn (Stayed or Left) Profile</h3>
#
# <div style = "display:fill;
#            border-colapse: colapse;
#            width: 50%;
#            margin: auto">
#
# <img style= "margin:auto" src="https://i.imgur.com/my21RZl.png" width = "6000">
#
# </div>
